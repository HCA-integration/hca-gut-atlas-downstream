# %%
from __future__ import annotations

from pathlib import Path

import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib as mpl
import matplotlib.pyplot as plt

# --- output folder (matches other GCA vignettes, see CAP_metrics / RareCellTypes) ---
GCA_ROOT = Path.home() / "Projects" / "GCA"
FIG_DIR = GCA_ROOT / "github_vignette_output" / "Prepub_vs_postPub"
FIG_DIR.mkdir(parents=True, exist_ok=True)

# --- Wong colorblind-safe palette (GCA plot_specs.md) ---
PAL = {
    "black":          "#000000",
    "vermillion":     "#D55E00",  # published / original / Taurus
    "hca_blue":       "#0072B2",  # consortium contributed / HGCA-derived
    "bluish_green":   "#009E73",  # secondary accent (agreement)
    "sky_blue":       "#56B4E9",
    "yellow":         "#F0E442",
    "reddish_purple": "#CC79A7",
    "light_grey":     "#E0E0E0",  # absent / null / background
    "mid_grey":       "#999999",
}

PAL_PROVENANCE = {
    "Published studies":          PAL["vermillion"],
    "Consortium contributed":     PAL["hca_blue"],
    "Published only":             PAL["vermillion"],
    "Published plus contributed": PAL["hca_blue"],
}


def setup_nature_style(font_size_pt: int = 6) -> None:
    """Apply Nature figure spec: Helvetica, 5–7 pt, thin axes, no gridlines."""
    mpl.rcParams.update({
        "font.family":          "sans-serif",
        "font.sans-serif":      ["Helvetica", "Helvetica Neue", "Arial", "DejaVu Sans"],
        "font.size":            font_size_pt,
        "axes.labelsize":       font_size_pt,
        "axes.titlesize":       min(font_size_pt + 1, 7),
        "figure.titlesize":     min(font_size_pt + 1, 7),
        "xtick.labelsize":      font_size_pt,
        "ytick.labelsize":      font_size_pt,
        "legend.fontsize":      font_size_pt,
        "legend.title_fontsize": font_size_pt,
        "text.color":           PAL["black"],
        "axes.labelcolor":      PAL["black"],
        "axes.edgecolor":       PAL["black"],
        "axes.titlecolor":      PAL["black"],
        "xtick.color":          PAL["black"],
        "ytick.color":          PAL["black"],
        "axes.linewidth":       0.5,
        "xtick.major.width":    0.5,
        "ytick.major.width":    0.5,
        "xtick.major.size":     2.0,
        "ytick.major.size":     2.0,
        "axes.spines.top":      False,
        "axes.spines.right":    False,
        "axes.grid":            False,
        "legend.frameon":       False,
        "pdf.fonttype":         42,   # editable text in Illustrator
        "ps.fonttype":          42,
        "figure.facecolor":     "white",
        "axes.facecolor":       "white",
        "savefig.facecolor":    "white",
        "savefig.transparent":  True,
    })


def mm_to_in(mm: float) -> float:
    return mm / 25.4


def figure_nature(width_mm: float = 90, height_mm: float = 60,
                  nrows: int = 1, ncols: int = 1, font_size_pt: int = 6,
                  **subplot_kwargs):
    """Make a figure at one of the Nature column widths (90 or 180 mm)."""
    setup_nature_style(font_size_pt=font_size_pt)
    return plt.subplots(
        nrows, ncols,
        figsize=(mm_to_in(width_mm), mm_to_in(height_mm)),
        **subplot_kwargs,
    )


def save_pdf(fig: mpl.figure.Figure, filename: str) -> Path:
    """Save figure to FIG_DIR as a vector PDF (Illustrator-editable)."""
    path = FIG_DIR / filename
    path.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(path, format="pdf", bbox_inches="tight", pad_inches=0.05)
    print(f"saved {path}")
    return path


setup_nature_style()
# Out:
# /Users/kylekimler/miniforge3/envs/scanpy/lib/python3.11/site-packages/louvain/__init__.py:54: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound

# %%
# adata = sc.read_h5ad('/Users/kylekimler/Projects/GCA/reference_mapping_benchmark/data/for_cap/myeloid.h5ad')

# %%
# for celltype in adata.obs['Prelim annotation'].unique():
#     print(celltype)

# %%
# for celltype in adata.obs['dataset_id'].unique():
#     print(celltype)

# %% [markdown]
# ## Something cool about the pre-pub data

# %%
paths = {
    "lymphoid": "/Users/kylekimler/Projects/GCA/reference_mapping_benchmark/data/for_cap/lymphoid.h5ad",
    "stroma": "/Users/kylekimler/Projects/GCA/reference_mapping_benchmark/data/for_cap/stroma.h5ad",
    "myeloid": "/Users/kylekimler/Projects/GCA/reference_mapping_benchmark/data/for_cap/myeloid.h5ad",
    "epithelial": "/Users/kylekimler/Projects/GCA/reference_mapping_benchmark/data/for_cap/epithelial.h5ad",
}

prepub_ids = {
    "ArendsHelmsley",
    "DominguezUnpub2",
    "DominguezUnpub",
    "BasuGCARNA",
    "KarakashevaHelmlsey",
}

tissue_col = "tissue_ontology_term"
ct_col = "Prelim annotation"
dataset_col = "dataset_id"
sym_col = "gene_symbol"

# %%
def segment_from_tissue(x):
    s = str(x).lower()
    if "duod" in s:
        return "duodenum"
    if "jejun" in s:
        return "jejunum"
    if "ile" in s:
        return "ileum"
    if "colon" in s or "large intestine" in s:
        return "colon"
    return "other"

def add_common_obs(ad):
    ad = ad.copy()
    ad.obs["segment_simple"] = ad.obs[tissue_col].map(segment_from_tissue)
    ad.obs["data_provenance"] = np.where(
        ad.obs[dataset_col].astype(str).isin(list(prepub_ids)),
        "Consortium contributed",
        "Published studies",
    )
    keep = ["duodenum", "jejunum", "ileum", "colon"]
    ad = ad[ad.obs["segment_simple"].isin(keep)].copy()
    return ad

def resolve_symbols_to_varnames(ad, symbols):
    if sym_col in ad.var.columns:
        s = ad.var[sym_col].astype(str).values
        out = []
        for g in symbols:
            idx = np.where(s == g)[0]
            if idx.size > 0:
                out.append(ad.var_names[int(idx[0])])
        return out
    return [g for g in symbols if g in ad.var_names]

adata_by_lineage = {k: add_common_obs(sc.read_h5ad(v)) for k, v in paths.items()}

# Plot A: show that consortium contributed data fills the jejunum immune gap.
# Saved at single-column width (90 mm) per plot_specs.md.
def plot_gap(ad, title, filename, width_mm=90, height_mm=60):
    seg_order = ["duodenum", "jejunum", "ileum", "colon"]
    prov_order = ["Published studies", "Consortium contributed"]
    tab = (
        pd.crosstab(ad.obs["segment_simple"], ad.obs["data_provenance"])
        .reindex(seg_order)
        .fillna(0)
    )
    tab = tab.reindex(columns=prov_order, fill_value=0)

    fig, ax = figure_nature(width_mm=width_mm, height_mm=height_mm)
    x = np.arange(len(seg_order))
    bottom = np.zeros(len(seg_order))
    for prov in prov_order:
        vals = tab[prov].to_numpy()
        ax.bar(
            x, vals,
            bottom=bottom,
            color=PAL_PROVENANCE[prov],
            edgecolor=PAL["black"],
            linewidth=0.25,
            label=prov,
        )
        bottom += vals

    ax.set_title(title)
    ax.set_xticks(x)
    ax.set_xticklabels(seg_order, rotation=45, ha="right")
    ax.set_xlabel("")
    ax.set_ylabel("Cell count")
    ax.yaxis.set_major_formatter(
        mpl.ticker.FuncFormatter(lambda v, _: f"{int(v):,}")
    )
    ax.legend(loc="upper left", bbox_to_anchor=(1.02, 1), title="")
    fig.tight_layout()
    save_pdf(fig, filename)
    plt.show()
    plt.close(fig)


plot_gap(adata_by_lineage["lymphoid"], "Lymphoid coverage",
         "prepub_lymphoid_coverage_by_segment.pdf")
plot_gap(adata_by_lineage["myeloid"], "Myeloid coverage",
         "prepub_myeloid_coverage_by_segment.pdf")
# Out:
# /Users/kylekimler/miniforge3/envs/scanpy/lib/python3.11/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/kylekimler/miniforge3/envs/scanpy/lib/python3.11/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/kylekimler/miniforge3/envs/scanpy/lib/python3.11/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/kylekimler/miniforge3/envs/scanpy/lib/python3.11/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# 1 extra bytes in post.stringData array
# ...

# %%
# Distribution of consortium-contributed (prepub) vs published (postpub) cells
# per lineage. Reuses adata_by_lineage built in the previous cell -- counts
# reflect cells in duodenum/jejunum/ileum/colon only, same filter as everything
# downstream. Single-column (90 mm) per plot_specs.md.

lineages = ["epithelial", "lymphoid", "myeloid", "stroma"]
prov_order = ["Published studies", "Consortium contributed"]

counts = pd.DataFrame(
    {
        prov: {
            lin: int((adata_by_lineage[lin].obs["data_provenance"] == prov).sum())
            for lin in lineages
        }
        for prov in prov_order
    },
    index=lineages,
)
counts["total"] = counts.sum(axis=1)
counts["pct_contributed"] = 100 * counts["Consortium contributed"] / counts["total"].clip(lower=1)
print(counts)

fig, ax = figure_nature(width_mm=90, height_mm=65)
x = np.arange(len(lineages))
bottom = np.zeros(len(lineages))
for prov in prov_order:
    vals = counts[prov].to_numpy()
    ax.bar(
        x, vals,
        bottom=bottom,
        color=PAL_PROVENANCE[prov],
        edgecolor=PAL["black"],
        linewidth=0.25,
        label=prov,
    )
    bottom += vals

ax.set_xticks(x)
ax.set_xticklabels(lineages, rotation=45, ha="right")
ax.set_xlabel("")
ax.set_ylabel("Cell count")
ax.yaxis.set_major_formatter(
    mpl.ticker.FuncFormatter(lambda v, _: f"{int(v):,}")
)
ax.legend(loc="upper left", bbox_to_anchor=(1.02, 1), title="")
fig.tight_layout()
save_pdf(fig, "prepub_provenance_distribution_by_lineage.pdf")
plt.show()
plt.close(fig)
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
#             Published studies  Consortium contributed   total  pct_contributed
# epithelial             163443                  103027  266470        38.663639
# lymphoid               308270                  232650  540920        43.010057
# myeloid                 28618                   21639   50257        43.056689
# stroma                  36704                   12213   48917        24.966780
# saved /Users/kylekimler/Projects/GCA/github_vignette_output/Prepub_vs_postPub/prepub_provenance_distribution_by_lineage.pdf

# %%
# Same data provenance split, now stratified by gut segment for every lineage.
# Double-column (180 mm) small-multiples panel per plot_specs.md: one subplot
# per lineage, x = segment (duodenum/jejunum/ileum/colon), stacked by provenance.

lineages = ["epithelial", "lymphoid", "myeloid", "stroma"]
prov_order = ["Published studies", "Consortium contributed"]
seg_order = ["duodenum", "jejunum", "ileum", "colon"]

fig, axes = figure_nature(width_mm=180, height_mm=60, ncols=len(lineages), sharey=True)
x = np.arange(len(seg_order))

for ax, lin in zip(axes, lineages):
    ad = adata_by_lineage[lin]
    tab = (
        pd.crosstab(ad.obs["segment_simple"], ad.obs["data_provenance"])
        .reindex(seg_order)
        .fillna(0)
        .reindex(columns=prov_order, fill_value=0)
    )
    bottom = np.zeros(len(seg_order))
    for prov in prov_order:
        vals = tab[prov].to_numpy()
        ax.bar(
            x, vals,
            bottom=bottom,
            color=PAL_PROVENANCE[prov],
            edgecolor=PAL["black"],
            linewidth=0.25,
            label=prov,
        )
        bottom += vals

    ax.set_title(lin)
    ax.set_xticks(x)
    ax.set_xticklabels(seg_order, rotation=45, ha="right")
    ax.set_xlabel("")

axes[0].set_ylabel("Cell count")
axes[0].yaxis.set_major_formatter(
    mpl.ticker.FuncFormatter(lambda v, _: f"{int(v):,}")
)
axes[-1].legend(loc="upper left", bbox_to_anchor=(1.02, 1), title="")

fig.tight_layout()
save_pdf(fig, "prepub_provenance_distribution_by_lineage_and_segment.pdf")
plt.show()
plt.close(fig)

# %%
prepub_ids = {
    "ArendsHelmsley",
    "DominguezUnpub2",
    "DominguezUnpub",
    "BasuGCARNA",
    "KarakashevaHelmlsey",
}

tissue_col = "tissue_ontology_term"
dataset_col = "dataset_id"
seg_col = "segment_simple"
sym_col = "gene_symbol"

def segment_from_tissue(x):
    s = str(x).lower()
    if "duod" in s:
        return "duodenum"
    if "jejun" in s:
        return "jejunum"
    if "ile" in s:
        return "ileum"
    if "colon" in s or "large intestine" in s:
        return "colon"
    return "other"

ad = adata_by_lineage["myeloid"]  # use your myeloid object here
ad.obs[seg_col] = ad.obs[tissue_col].map(segment_from_tissue)

ad.obs["is_prepub"] = ad.obs[dataset_col].astype(str).isin(list(prepub_ids))
ad.obs["provenance"] = np.where(ad.obs["is_prepub"], "Consortium contributed", "Published studies")

seg_order = ["duodenum", "jejunum", "ileum", "colon"]
ad = ad[ad.obs[seg_col].isin(seg_order)].copy()
ad.obs[seg_col] = pd.Categorical(ad.obs[seg_col].astype(str), categories=seg_order, ordered=True)

ad_pub = ad[ad.obs["provenance"] == "Published studies"].copy()
ad_all = ad.copy()

markers = {
    "Lacteal support": ["VEGFC", "CSF1R", "CX3CR1", "MRC1"],
    "Lipid handling": ["APOE", "LPL", "CD36", "FABP5", "TREM2"],
}

mac_mask = ad.obs[ct_col].astype(str).str.contains("mac|mdm|mono", case=False, regex=True)
mac = ad[mac_mask].copy()

seg_order = ["duodenum","jejunum","ileum","colon"]
mac.obs["segment_simple"] = pd.Categorical(mac.obs["segment_simple"].astype(str), categories=seg_order, ordered=True)

mac_pub = mac[mac.obs["provenance"] == "Published studies"].copy()
mac_all = mac.copy()

markers = {
    "Lacteal support": ["CX3CR1", "MYD88"],
    "Lipid handling": ["TREM2", "APOE"],
}

# Double-column (180 mm) paired dotplot per plot_specs.md.
setup_nature_style()
fig, axes = plt.subplots(
    1, 2,
    figsize=(mm_to_in(180), mm_to_in(70)),
    sharey=True,
)

sc.pl.dotplot(
    mac_pub,
    var_names=markers,
    groupby="segment_simple",
    gene_symbols=sym_col if sym_col in mac_pub.var.columns else None,
    standard_scale="var",
    dot_max=0.7,
    ax=axes[0],
    show=False,
)
axes[0].set_title("Published studies only")

sc.pl.dotplot(
    mac_all,
    var_names=markers,
    groupby="segment_simple",
    gene_symbols=sym_col if sym_col in mac_all.var.columns else None,
    standard_scale="var",
    dot_max=0.7,
    ax=axes[1],
    show=False,
)
axes[1].set_title("Published plus contributed")

fig.tight_layout()
save_pdf(fig, "prepub_myeloid_macrophage_marker_dotplot.pdf")
plt.show()
plt.close(fig)
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# saved /Users/kylekimler/Projects/GCA/github_vignette_output/Prepub_vs_postPub/prepub_myeloid_macrophage_marker_dotplot.pdf

# %%
# Side-by-side count of myeloid cells per segment, published vs published+contributed.
# Single-column (90 mm) per plot_specs.md.
# NOTE: depends on ad_pub / ad_all / seg_col / seg_order defined in the next cell.
tab_pub = ad_pub.obs[seg_col].value_counts().reindex(seg_order).fillna(0)
tab_all = ad_all.obs[seg_col].value_counts().reindex(seg_order).fillna(0)
df = pd.DataFrame({"Published only": tab_pub, "Published plus contributed": tab_all})

fig, ax = figure_nature(width_mm=90, height_mm=60)
x = np.arange(len(seg_order))
bar_w = 0.4
ax.bar(x - bar_w / 2, df["Published only"].to_numpy(),
       width=bar_w, color=PAL_PROVENANCE["Published only"],
       edgecolor=PAL["black"], linewidth=0.25, label="Published only")
ax.bar(x + bar_w / 2, df["Published plus contributed"].to_numpy(),
       width=bar_w, color=PAL_PROVENANCE["Published plus contributed"],
       edgecolor=PAL["black"], linewidth=0.25, label="Published plus contributed")

ax.set_xticks(x)
ax.set_xticklabels(seg_order, rotation=45, ha="right")
ax.set_xlabel("")
ax.set_ylabel("Cells")
ax.yaxis.set_major_formatter(
    mpl.ticker.FuncFormatter(lambda v, _: f"{int(v):,}")
)
ax.legend(loc="upper left", bbox_to_anchor=(1.02, 1), title="")
fig.tight_layout()
save_pdf(fig, "prepub_myeloid_published_vs_contributed_by_segment.pdf")
plt.show()
plt.close(fig)
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# saved /Users/kylekimler/Projects/GCA/github_vignette_output/Prepub_vs_postPub/prepub_myeloid_published_vs_contributed_by_segment.pdf

# %%
# adata.obs['provenance'].value_counts()

# %%
from scipy.stats import ranksums
from statsmodels.stats.multitest import multipletests

adata = adata_by_lineage["myeloid"]  

adata.obs["segment_simple"] = adata.obs[tissue_col].map(segment_from_tissue)
adata = adata[adata.obs["segment_simple"].isin(["duodenum", "jejunum", "ileum", "colon"])].copy()

adata.obs["provenance"] = np.where(
    adata.obs[dataset_col].astype(str).isin(list(prepub_ids)),
    "Contributed",
    "Published",
)

def varname_for_symbol(ad, symbol):
    if sym_col in ad.var.columns:
        s = ad.var[sym_col].astype(str).values
        idx = np.where(s == symbol)[0]
        if idx.size > 0:
            return ad.var_names[int(idx[0])]
        return None
    if symbol in ad.var_names:
        return symbol
    return None

def get_expr(ad, gene_varname):
    x = ad[:, [gene_varname]].X
    if hasattr(x, "toarray"):
        x = x.toarray()
    return np.asarray(x).reshape(-1)

def compute_gene_celltype_tests(ad, gene_symbols, seg_a="jejunum", seg_b="ileum", min_cells=50):
    out = []
    for ct in ad.obs[ct_col].astype(str).unique():
        sub = ad[ad.obs[ct_col].astype(str) == ct].copy()
        a_mask = sub.obs["segment_simple"].astype(str) == seg_a
        b_mask = sub.obs["segment_simple"].astype(str) == seg_b
        na = int(a_mask.sum())
        nb = int(b_mask.sum())
        if na < min_cells or nb < min_cells:
            continue

        for gsym in gene_symbols:
            gvar = varname_for_symbol(sub, gsym)
            if gvar is None:
                continue
            xa = get_expr(sub[a_mask], gvar)
            xb = get_expr(sub[b_mask], gvar)

            stat, p = ranksums(xa, xb)

            med_a = float(np.median(xa))
            med_b = float(np.median(xb))
            lfc = float(np.log2((med_a + 1e-3) / (med_b + 1e-3)))

            out.append(
                {
                    "celltype": ct,
                    "gene": gsym,
                    "na": na,
                    "nb": nb,
                    "median_a": med_a,
                    "median_b": med_b,
                    "log2_fc": lfc,
                    "p": float(p),
                }
            )
    df = pd.DataFrame(out)
    if df.shape[0] == 0:
        return df
    df["q"] = multipletests(df["p"].values, method="fdr_bh")[1]
    return df

genes = ["MYD88", "APOE", "IL1B", "TNF", "NFKBIA", "CXCL8"]

pub = adata[adata.obs["provenance"] == "Published"].copy()
all_data = adata.copy()

res_pub = compute_gene_celltype_tests(pub, genes, seg_a="jejunum", seg_b="ileum", min_cells=50)
res_all = compute_gene_celltype_tests(all_data, genes, seg_a="jejunum", seg_b="ileum", min_cells=50)

res_pub["dataset_set"] = "Published only"
res_all["dataset_set"] = "Published plus contributed"

res = pd.concat([res_pub, res_all], ignore_index=True)

res_counts = (
    res.groupby(["dataset_set", "celltype"])
    .apply(lambda x: pd.Series({"sig_genes_q05": int((x["q"] < 0.05).sum())}))
    .reset_index()
)
# Out:
# /var/folders/zc/5fly3ly908xb0pd8zy6m6bj80000gn/T/ipykernel_3624/1682764132.py:89: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: pd.Series({"sig_genes_q05": int((x["q"] < 0.05).sum())}))

# %%
res_pub
# Out:
# Empty DataFrame
# Columns: [dataset_set]
# Index: []

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt

prepub_ids = {
    "ArendsHelmsley",
    "DominguezUnpub2",
    "DominguezUnpub",
    "BasuGCARNA",
    "KarakashevaHelmlsey",
}

path_myeloid = "/Users/kylekimler/Projects/GCA/reference_mapping_benchmark/data/for_cap/myeloid.h5ad"
adata = sc.read_h5ad(path_myeloid)

tissue_col = "tissue_ontology_term"
dataset_col = "dataset_id"
ct_col = "Prelim annotation"

uberon_to_segment = {
    "UBERON:0002114": "duodenum",
    "UBERON:0002115": "jejunum",
    "UBERON:0002116": "ileum",
    "UBERON:0001155": "colon",
}

def segment_from_tissue(x):
    s = str(x)
    if s in uberon_to_segment:
        return uberon_to_segment[s]
    sl = s.lower()
    if "duod" in sl:
        return "duodenum"
    if "jejun" in sl:
        return "jejunum"
    if "ile" in sl:
        return "ileum"
    if "colon" in sl or "large intestine" in sl:
        return "colon"
    return "other"

ad = adata.copy()
ad.obs["segment_simple"] = ad.obs[tissue_col].map(segment_from_tissue)
ad = ad[ad.obs["segment_simple"].isin(["duodenum", "jejunum", "ileum", "colon"])].copy()

ad.obs["provenance"] = np.where(
    ad.obs[dataset_col].astype(str).isin(list(prepub_ids)),
    "Contributed",
    "Published",
)

celltypes_wanted = [
    "Macrophages Cycling",
    "Macrophages Tissue Resident",
    "DC cDC2",
    "DC cDC1",
    "DC migDC",
    "Monocytes",
    "doublet",
    "Fibroblasts Follicular Dendritic Cells (fDC)",
    "Macrophages M2",
    "Granulocytes Mast Cells",
    "DC Monocyte derived dendritic cell\n(MO DC)",
    "Granulocytes",
]

celltypes_present = set(ad.obs[ct_col].astype(str).unique().tolist())
celltypes = [ct for ct in celltypes_wanted if ct in celltypes_present]
if len(celltypes) == 0:
    celltypes = sorted(list(celltypes_present))

comparisons = [
    ("duodenum", "jejunum", "duodenum vs jejunum"),
    ("jejunum", "ileum", "jejunum vs ileum"),
]

def sanitize_log1p_uns(a):
    if "log1p" in a.uns and not isinstance(a.uns["log1p"], dict):
        a.uns["log1p"] = {}

def de_count_for_celltype(ad_in, celltype, seg_a, seg_b, min_cells=50, q_cut=0.05):
    sub = ad_in[ad_in.obs[ct_col].astype(str) == str(celltype)].copy()
    sub = sub[sub.obs["segment_simple"].isin([seg_a, seg_b])].copy()

    na = int((sub.obs["segment_simple"].astype(str) == seg_a).sum())
    nb = int((sub.obs["segment_simple"].astype(str) == seg_b).sum())
    if na < min_cells or nb < min_cells:
        return np.nan, na, nb

    sanitize_log1p_uns(sub)

    sc.tl.rank_genes_groups(
        sub,
        groupby="segment_simple",
        groups=[seg_a],
        reference=seg_b,
        method="wilcoxon",
        use_raw=False,
    )

    df = sc.get.rank_genes_groups_df(sub, group=seg_a)
    if "pvals_adj" not in df.columns:
        return np.nan, na, nb

    n_sig = int((df["pvals_adj"].values < q_cut).sum())
    return n_sig, na, nb

import pandas as pd

def check_celltype_segment_presence(ad, ct_col="Prelim annotation"):
    tab = pd.crosstab(ad.obs[ct_col].astype(str), ad.obs["segment_simple"].astype(str))
    tab = tab.reindex(columns=["duodenum", "jejunum", "ileum", "colon"], fill_value=0)
    return tab

tab_pub = check_celltype_segment_presence(ad_pub, ct_col=ct_col)
tab_all = check_celltype_segment_presence(ad_all, ct_col=ct_col)

print("Published only, cells per celltype per segment")
print(tab_pub.loc[:, ["duodenum", "jejunum", "ileum", "colon"]].sort_index())

print("\nPublished plus contributed, cells per celltype per segment")
print(tab_all.loc[:, ["duodenum", "jejunum", "ileum", "colon"]].sort_index())
# Out:
# /Users/kylekimler/miniforge3/envs/scanpy/lib/python3.11/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Published only, cells per celltype per segment
# segment_simple                                duodenum  jejunum  ileum  colon
# Prelim annotation
# DC Monocyte derived dendritic cell\n(MO DC)          0        0     91     16
# DC cDC1                                              0        2    839     96
# DC cDC2                                             18        4   3518    519
# DC migDC                                             0        0    267     48
# Fibroblasts Follicular Dendritic Cells (fDC)         0        0    137      0
# Granulocytes                                         0        0     26      0
# Granulocytes Mast Cells                            203       11   1752   1564
# ...

# %%
def de_count_for_celltype(ad_in, celltype, seg_a, seg_b, min_cells=50, fdr_cut=0.05):
    sub = ad_in[ad_in.obs[ct_col].astype(str) == str(celltype)].copy()
    sub = sub[sub.obs["segment_simple"].isin([seg_a, seg_b])].copy()

    na = int((sub.obs["segment_simple"].astype(str) == seg_a).sum())
    nb = int((sub.obs["segment_simple"].astype(str) == seg_b).sum())
    if na < min_cells or nb < min_cells:
        return np.nan, na, nb

    sanitize_log1p_uns(sub)

    sc.pp.normalize_total(sub, target_sum=1e4)
    sc.pp.log1p(sub)
    sanitize_log1p_uns(sub)

    sc.tl.rank_genes_groups(
        sub,
        groupby="segment_simple",
        groups=[seg_a],
        reference=seg_b,
        method="wilcoxon",
        use_raw=False,
    )

    df = sc.get.rank_genes_groups_df(sub, group=seg_a)
    if "pvals_adj" not in df.columns:
        return np.nan, na, nb

    n_sig = int((df["pvals_adj"].values < fdr_cut).sum())
    return n_sig, na, nb

def build_matrix(ad_in, min_cells=50, fdr_cut=0.001):
    mat = pd.DataFrame(index=celltypes, columns=[c[2] for c in comparisons], dtype=float)
    nobs = pd.DataFrame(index=celltypes, columns=[c[2] for c in comparisons], dtype=object)

    for ct in celltypes:
        for seg_a, seg_b, cname in comparisons:
            n_sig, na, nb = de_count_for_celltype(ad_in, ct, seg_a, seg_b, min_cells=min_cells, fdr_cut=fdr_cut)
            mat.loc[ct, cname] = n_sig
            nobs.loc[ct, cname] = str(na) + "/" + str(nb)

    return mat, nobs

mat_pub, nobs_pub = build_matrix(ad_pub, min_cells=50, fdr_cut=0.0001)
mat_all, nobs_all = build_matrix(ad_all, min_cells=50, fdr_cut=0.0001)

# Fill sub-threshold (NaN) comparisons with 0 so both subplots take the EXACT
# same render path. Using imshow + cmap.set_bad(light_grey) writes the masked
# cells through matplotlib's alpha channel, which Illustrator color-shifts
# inconsistently between the two embedded rasters (one panel ends up blue,
# the other grey on cmd+P). Drawing every cell as an explicit vector rectangle
# with an explicit RGB fill keeps both subplots identical in Illustrator and
# makes them fully editable (no raster preview involved).
import matplotlib.colors as mcolors
from matplotlib.patches import Rectangle
from matplotlib.cm import ScalarMappable

mat_pub_filled = mat_pub.astype(float).fillna(0.0)
mat_all_filled = mat_all.astype(float).fillna(0.0)
nobs_pub_grid = nobs_pub.reindex_like(mat_pub_filled)
nobs_all_grid = nobs_all.reindex_like(mat_all_filled)

vmax = float(np.nanmax([mat_pub_filled.values.max(), mat_all_filled.values.max()]))
if not np.isfinite(vmax) or vmax <= 0:
    vmax = 1.0

cmap = plt.cm.viridis
norm = mcolors.Normalize(vmin=0, vmax=vmax)

# Double-column (180 mm) heatmap per plot_specs.md.
fig, axes = figure_nature(width_mm=180, height_mm=110, ncols=2, sharey=True)


def _draw_vector_heatmap(ax, mat, nobs, title):
    nrows, ncols = mat.shape
    arr = mat.values
    for i in range(nrows):
        for j in range(ncols):
            val = float(arr[i, j])
            rgba = cmap(norm(val))
            ax.add_patch(Rectangle(
                (j - 0.5, i - 0.5), 1, 1,
                facecolor=rgba,
                edgecolor=PAL["black"],
                linewidth=0.1,
            ))
            txt_color = "white" if val < vmax * 0.55 else PAL["black"]
            count_label = f"{int(round(val)):,}"
            ax.text(j, i, count_label,
                    ha="center", va="center", fontsize=5, color=txt_color)
            # Bottom-right corner: cell counts behind the comparison (n_a/n_b).
            n_str = nobs.iat[i, j] if nobs is not None else ""
            if isinstance(n_str, str) and "/" in n_str:
                ax.text(j + 0.45, i + 0.45, n_str,
                        ha="right", va="bottom", fontsize=3.5, color=txt_color,
                        alpha=0.75)

    ax.set_xlim(-0.5, ncols - 0.5)
    ax.set_ylim(nrows - 0.5, -0.5)  # invert y so row 0 is on top
    ax.set_aspect("auto")
    ax.set_title(title)
    ax.set_xticks(range(ncols))
    ax.set_xticklabels(mat.columns, rotation=45, ha="right")
    ax.set_yticks(range(nrows))
    ax.set_yticklabels(mat.index)
    for s in ax.spines.values():
        s.set_visible(False)
    ax.tick_params(length=0)


_draw_vector_heatmap(axes[0], mat_pub_filled, nobs_pub_grid, "Published only")
_draw_vector_heatmap(axes[1], mat_all_filled, nobs_all_grid, "Published plus contributed")

sm = ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])
cbar = fig.colorbar(sm, ax=axes, fraction=0.025, pad=0.02)
cbar.set_label("DE genes (FDR < 1\u00d710\u207B\u2074)")
cbar.outline.set_linewidth(0.25)
cbar.ax.tick_params(width=0.25)

fig.suptitle("Jejunum vs ileum DE-gene counts per cell type", y=0.99)
save_pdf(fig, "prepub_myeloid_de_gene_counts_jejunum_vs_ileum.pdf")
plt.show()
plt.close(fig)
# Out:
# WARNING: adata.X seems to be already log-transformed.
# WARNING: adata.X seems to be already log-transformed.
# WARNING: adata.X seems to be already log-transformed.
# WARNING: adata.X seems to be already log-transformed.
# WARNING: adata.X seems to be already log-transformed.
# WARNING: adata.X seems to be already log-transformed.
# WARNING: adata.X seems to be already log-transformed.
# WARNING: adata.X seems to be already log-transformed.
# WARNING: adata.X seems to be already log-transformed.
# WARNING: adata.X seems to be already log-transformed.
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# saved /Users/kylekimler/Projects/GCA/github_vignette_output/Prepub_vs_postPub/prepub_myeloid_de_gene_counts_jejunum_vs_ileum.pdf

# %%
# fig, axes = plt.subplots(1, 2, figsize=(9.5, 5.5), sharey=True)

# for ax, mat, title in [
#     (axes[0], mat_pub, "Published only"),
#     (axes[1], mat_all, "Published plus contributed"),
# ]:
#     arr = mat.values.astype(float)
#     im = ax.imshow(arr, aspect="auto", cmap=cmap, vmin=0, vmax=vmax)

#     ax.set_title(title)
#     ax.set_xticks(range(mat.shape[1]))
#     ax.set_xticklabels(mat.columns, rotation=45, ha="right")

#     ax.set_yticks(range(mat.shape[0]))
#     ax.set_yticklabels(mat.index)

#     for i in range(mat.shape[0]):
#         for j in range(mat.shape[1]):
#             val = arr[i, j]
#             if np.isfinite(val):
#                 ax.text(j, i, str(int(val)), ha="center", va="center", fontsize=8)

# cbar = fig.colorbar(im, ax=axes, shrink=0.9)
# cbar.set_label("Number of DE genes with q < 0.05")

# plt.tight_layout()
# plt.show()

# %%
# import scanpy as sc
# import numpy as np

# print(type(adata.uns))
# print(adata.uns)

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# def stars(q):
#     if q < 1e-3:
#         return "***"
#     if q < 1e-2:
#         return "**"
#     if q < 5e-2:
#         return "*"
#     return ""

# genes_show = ["MYD88", "APOE"]

# sub = res[res["gene"].isin(genes_show)].copy()

# for gene in genes_show:
#     df = sub[sub["gene"] == gene].pivot(index="celltype", columns="dataset_set", values="log2_fc")
#     df = df.reindex(index=cts)
#     fig, ax = plt.subplots(figsize=(5.2, 0.35 * max(6, df.shape[0])))
#     im = ax.imshow(df.values, aspect="auto")
#     ax.set_yticks(range(df.shape[0]))
#     ax.set_yticklabels(df.index)
#     ax.set_xticks(range(df.shape[1]))
#     ax.set_xticklabels(df.columns, rotation=30, ha="right")
#     ax.set_title(gene + " log2FC (jejunum vs ileum)")

#     for i, ct in enumerate(df.index):
#         for j, ds in enumerate(df.columns):
#             qv = sub[(sub["gene"] == gene) & (sub["celltype"] == ct) & (sub["dataset_set"] == ds)]["q"]
#             if qv.shape[0] == 1:
#                 ax.text(j, i, stars(float(qv.iloc[0])), ha="center", va="center")

#     plt.tight_layout()
#     plt.show()

# %% [markdown]
# ## Jejunum myeloid compositions

# %%
adata = sc.read_h5ad("/Users/kylekimler/Projects/GCA/reference_mapping_benchmark/data/for_cap/myeloid.h5ad")

tissue_col = "tissue_ontology_term"
ct_col = "Prelim annotation"

uberon_to_segment = {
    "UBERON:0002114": "duodenum",
    "UBERON:0002115": "jejunum",
    "UBERON:0002116": "ileum",
    "UBERON:0001155": "colon",
}

def segment_from_tissue(x):
    s = str(x)
    if s in uberon_to_segment:
        return uberon_to_segment[s]
    sl = s.lower()
    if "duod" in sl:
        return "duodenum"
    if "jejun" in sl:
        return "jejunum"
    if "ile" in sl:
        return "ileum"
    if "colon" in sl or "large intestine" in sl:
        return "colon"
    return "other"

seg_order = ["duodenum", "jejunum", "ileum", "colon"]

ad = adata.copy()
ad.obs["segment_simple"] = ad.obs[tissue_col].map(segment_from_tissue)
ad = ad[ad.obs["segment_simple"].isin(seg_order)].copy()

counts = pd.crosstab(ad.obs["segment_simple"], ad.obs[ct_col].astype(str)).reindex(seg_order).fillna(0)

pseudocount = 0.5
x = counts.astype(float) + pseudocount
x = x.div(x.sum(axis=1), axis=0)

logx = np.log(x.values)
clr = logx - logx.mean(axis=1, keepdims=True)
clr_df = pd.DataFrame(clr, index=counts.index, columns=counts.columns)

short = {
    "Macrophages Tissue Resident": "Mac TRM",
    "Macrophages M2": "Mac M2",
    "Macrophages Cycling": "Mac cyc",
    "Monocytes": "Mono",
    "DC cDC1": "cDC1",
    "DC cDC2": "cDC2",
    "DC migDC": "migDC",
    "DC Monocyte derived dendritic cell\n(MO DC)": "MO DC",
    "Granulocytes": "Gran",
    "Granulocytes Mast Cells": "Mast",
    "Fibroblasts Follicular Dendritic Cells (fDC)": "fDC",
    "doublet": "dblt",
}

def ct_group(ct):
    s = str(ct).lower()
    if "macrophage" in s:
        return "Macrophage"
    if "monocyte" in s:
        return "Monocyte"
    if "dc" in s or "dendritic" in s:
        return "DC"
    if "granulocyte" in s or "mast" in s:
        return "Granulocyte"
    return "Other"

meta = pd.DataFrame({"ct": clr_df.columns})
meta["group"] = meta["ct"].map(ct_group)
meta["short"] = meta["ct"].map(lambda x: short.get(x, str(x)))

group_order = ["Macrophage", "Monocyte", "DC", "Granulocyte", "Other"]
meta["group"] = pd.Categorical(meta["group"], categories=group_order, ordered=True)

meta = meta.sort_values(["group", "short"])
meta = meta[meta["ct"].astype(str) != "doublet"].copy()

ct_order = meta["ct"].tolist()
clr_df = clr_df[ct_order]

mat = clr_df.values.T
row_labels = meta["short"].tolist()

v = float(np.nanquantile(np.abs(mat), 0.95))
if not np.isfinite(v) or v == 0:
    v = 1.0

# Single-column (90 mm) per plot_specs.md. CLR diverging cmap is
# colorblind-safe (blue ↔ red around white center).
fig, ax = figure_nature(width_mm=90, height_mm=110)
im = ax.imshow(mat, vmin=-v, vmax=v, cmap="RdBu_r", aspect="equal")

ax.set_xticks(range(len(seg_order)))
ax.set_xticklabels(seg_order, rotation=45, ha="right")
import matplotlib.transforms as mtransforms

dx_pts = 5
offset = mtransforms.ScaledTranslation(dx_pts / 72.0, 0, fig.dpi_scale_trans)
for lab in ax.get_xticklabels():
    lab.set_transform(lab.get_transform() + offset)

ax.set_yticks(range(len(row_labels)))
ax.set_yticklabels(row_labels)

ax.yaxis.set_ticks_position("left")
ax.tick_params(axis="y", pad=4, length=0)
ax.tick_params(axis="x", length=0)
for s in ax.spines.values():
    s.set_visible(False)

ax.set_title("Myeloid composition")

group_sizes = meta["group"].value_counts().reindex(group_order).fillna(0).astype(int).tolist()
pos = 0
for gs in group_sizes:
    if gs > 0:
        pos += gs
        ax.axhline(pos - 0.5, color=PAL["black"], linewidth=0.5)

cbar = fig.colorbar(im, ax=ax, fraction=0.046, pad=0.03)
cbar.set_label("CLR")
cbar.outline.set_linewidth(0.25)
cbar.ax.tick_params(width=0.25)

fig.tight_layout()
save_pdf(fig, "prepub_myeloid_composition_clr_heatmap.pdf")
plt.show()
plt.close(fig)
