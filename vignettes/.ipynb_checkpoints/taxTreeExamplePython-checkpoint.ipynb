# %%
import pandas as pd

class TreeNode:
    def __init__(self, name):
        self.name = name
        self.children = {}
        self.metadata = {}

    def add_child(self, node_name):
        if node_name not in self.children:
            self.children[node_name] = TreeNode(node_name)
        return self.children[node_name]

def build_tree_from_taxonomy(
    csv_path: str,
    resolution_cols: list[str],
    annotation_cols: list[str] | None = None
) -> TreeNode:
    df = pd.read_csv(csv_path, dtype=str).fillna("")
    if annotation_cols is None:
        # everything not in resolutions becomes metadata
        annotation_cols = [c for c in df.columns if c not in resolution_cols]
    root = TreeNode("root")
    for _, row in df.iterrows():
        node = root
        # descend/create according to each resolution column
        for col in resolution_cols:
            val = row[col]
            if not val:
                break
            node = node.add_child(val)
        # attach all other columns as metadata on the leaf
        for col in annotation_cols:
            node.metadata[col] = row[col]
    return root

# %%
path = "/Users/kylekimler/Projects/GCA/ontology/gca_celltype_taxonomy.csv"
resolutions = ["Lineage", "Differentia", "Habitus", "Status", "Whim"]
extras = ["closest_GCA_celltype", "markers"]
tree = build_tree_from_taxonomy(path, resolutions, extras)

# %%
import matplotlib.pyplot as plt

def pretty_print(node, indent=0):
    """Recursively print out node names with indentation."""
    print("  " * indent + node.name)
    for child in node.children.values():
        pretty_print(child, indent + 1)


def plot_tree(node):
    """
    Assign each node an (x,y) based on depth and leaf order,
    then draw lines + labels in matplotlib.
    """
    # 1) Compute positions
    positions = {}
    def _assign(n, depth=0, counter=[0]):
        # if leaf, give it the next y
        if not n.children:
            y = counter[0]
            positions[n] = (depth, y)
            counter[0] += 1
        else:
            # assign positions for children first
            child_ys = []
            for c in n.children.values():
                _assign(c, depth + 1, counter)
                child_ys.append(positions[c][1])
            # place this node midway between its children
            positions[n] = (depth, sum(child_ys) / len(child_ys))
    _assign(node)

    # 2) Plot edges
    fig, ax = plt.subplots()
    for parent, (x1, y1) in positions.items():
        for child in parent.children.values():
            x2, y2 = positions[child]
            ax.plot([x1, x2], [y1, y2])  # default color

    # 3) Plot labels
    for n, (x, y) in positions.items():
        ax.text(x, y, n.name, va="center", ha="right" if n.children else "left",
                fontsize=8)

    ax.invert_yaxis()   # so top of tree is at the top
    ax.axis("off")
    plt.tight_layout()
    plt.show()

plot_tree(tree)

# %%
def flatten(node, order, depths, depth=0):
    order.append(node)
    depths.append(depth)
    for child in node.children.values():
        flatten(child, order, depths, depth+1)
    return order, depths

# 1) flatten
nodes, depths = flatten(tree, [], [])

# 2) build your matrix (here random for demo)
import pandas as pd, numpy as np
M = pd.DataFrame(
    np.random.rand(len(nodes), len(nodes)),
    index=[n.name for n in nodes],
    columns=[n.name for n in nodes]
)

# 3) find boundaries at a given depth, e.g. depth=1
boundaries = []
last = depths[0]
for i,d in enumerate(depths):
    if d < last:
        boundaries.append(i)
    last = d
# also add final boundary
boundaries.append(len(nodes))

# 4) plot with separators
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(6,6))
cax = ax.matshow(M, aspect='auto')
for b in boundaries:
    ax.axhline(b-0.5, color='white')
    ax.axvline(b-0.5, color='white')

# optional side‑bar for depth
ax2 = fig.add_axes([0.91, 0.1, 0.02, 0.8])
ax2.barh(range(len(nodes)), [1]*len(nodes), height=1, 
         left=0, color=plt.cm.tab20(depths))
ax2.set_xticks([])
ax2.set_yticks([])

ax.set_xticks(range(len(nodes)))
ax.set_xticklabels([n.name for n in nodes], rotation=90, fontsize=6)
ax.set_yticks(range(len(nodes)))
ax.set_yticklabels([n.name for n in nodes], fontsize=6)

plt.tight_layout(rect=[0,0,0.9,1])
plt.show()
# Out:
# /var/folders/zc/5fly3ly908xb0pd8zy6m6bj80000gn/T/ipykernel_22753/2927126440.py:49: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0,0,0.9,1])

# %%
# %matplotlib widget

import matplotlib.pyplot as plt

# assume `nodes`, `depths`, `M`, and `boundaries` are already defined
n = len(nodes)
fs = 6                  # tick‐label font size in pts
scale = fs / 5          # inches per node
w = max(8, n * scale)   # min width of 8"
h = max(8, n * scale)   # min height of 8"

fig, ax = plt.subplots(figsize=(w, h))
cax = ax.matshow(M, aspect='auto')

# draw split lines
for b in boundaries:
    ax.axhline(b - 0.5, color='white', lw=1)
    ax.axvline(b - 0.5, color='white', lw=1)

# ticks
labels = [n.name for n in nodes]
ax.set_xticks(range(n))
ax.set_xticklabels(labels, rotation=90, fontsize=fs)
ax.set_yticks(range(n))
ax.set_yticklabels(labels, fontsize=fs)

ax.invert_yaxis()
ax.axis('off')
plt.tight_layout()
plt.show()

# %%
# %pip install ipympl
# Out:
# Collecting ipympl
#   Downloading ipympl-0.9.7-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: ipython<10 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from ipympl) (8.24.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from ipympl) (8.1.2)
# Requirement already satisfied: matplotlib<4,>=3.5.0 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from ipympl) (3.8.2)
# Requirement already satisfied: numpy in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from ipympl) (1.26.4)
# Requirement already satisfied: pillow in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from ipympl) (10.2.0)
# Requirement already satisfied: traitlets<6 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: decorator in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from ipython<10->ipympl) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from ipython<10->ipympl) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from ipython<10->ipympl) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from ipython<10->ipympl) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from ipython<10->ipympl) (2.17.2)
# Requirement already satisfied: stack-data in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from ipython<10->ipympl) (0.6.3)
# Requirement already satisfied: typing-extensions>=4.6 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from ipython<10->ipympl) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from ipython<10->ipympl) (4.9.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.10)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from matplotlib<4,>=3.5.0->ipympl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from matplotlib<4,>=3.5.0->ipympl) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from matplotlib<4,>=3.5.0->ipympl) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from matplotlib<4,>=3.5.0->ipympl) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from matplotlib<4,>=3.5.0->ipympl) (2.8.2)
# Requirement already satisfied: wcwidth in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<10->ipympl) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from jedi>=0.16->ipython<10->ipympl) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pexpect>4.3->ipython<10->ipympl) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.5.0->ipympl) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from stack-data->ipython<10->ipympl) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from stack-data->ipython<10->ipympl) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from stack-data->ipython<10->ipympl) (0.2.2)
# Downloading ipympl-0.9.7-py3-none-any.whl (515 kB)
# Installing collected packages: ipympl
# Successfully installed ipympl-0.9.7
# Note: you may need to restart the kernel to use updated packages.
