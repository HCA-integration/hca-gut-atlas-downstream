# %%
import re
import numpy as np
import pandas as pd
import requests
from io import BytesIO
import matplotlib.pyplot as plt
from openpyxl import load_workbook

# Plotting params
palette = [
    "#1b9e77",
    "#d95f02",
    "#7570b3",
    "#e7298a",
    "#66a61e",
    "#e6ab02",
    "#a6761d",
    "#666666",
]

plt.rcParams.update({
    "font.size": 11,
    "axes.titlesize": 13,
    "axes.labelsize": 12,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
    "axes.linewidth": 1.0,
})


URL = "https://cdn.who.int/media/docs/default-source/gho-documents/global-health-estimates/ghe2021_daly_global_new.xlsx?sfvrsn=cbefe871_2"

def download_ghe_xlsx(url=URL, timeout=120):
    r = requests.get(url, timeout=timeout)
    r.raise_for_status()
    return BytesIO(r.content)

def _cell_str(x):
    if x is None:
        return None
    s = str(x).strip()
    return s if s else None

def parse_global_sheet_to_taxonomy(xlsx_bytes, sheet_name="Global 2021"):
    xlsx_bytes.seek(0)
    wb = load_workbook(xlsx_bytes, data_only=True)
    ws = wb[sheet_name]

    region = _cell_str(ws.cell(3, 6).value)
    year = ws.cell(4, 6).value
    try:
        year = int(year)
    except Exception:
        year = int(re.findall(r"\d{4}", sheet_name)[0])

    lvl0_main = None
    lvl0_sub = None
    lvl1 = None
    lvl2 = None

    num_pat = re.compile(r"^\d+\.$")
    sub_pat = re.compile(r"^[A-Z]\.$")
    leaf_pat = re.compile(r"^[a-z]\.$", re.IGNORECASE)

    male_age_cols = [
        ("0_28_days", 10),
        ("1_59_months", 11),
        ("5_14", 12),
        ("15_29", 13),
        ("30_49", 14),
        ("50_59", 15),
        ("60_69", 16),
        ("70_plus", 17),
    ]
    female_age_cols = [
        ("0_28_days", 18),
        ("1_59_months", 19),
        ("5_14", 20),
        ("15_29", 21),
        ("30_49", 22),
        ("50_59", 23),
        ("60_69", 24),
        ("70_plus", 25),
    ]

    def to_num(x):
        try:
            return float(x)
        except Exception:
            return np.nan

    out = []
    for r in range(10, ws.max_row + 1):
        code = ws.cell(r, 1).value

        c3 = _cell_str(ws.cell(r, 3).value)
        c4 = _cell_str(ws.cell(r, 4).value)
        c5 = _cell_str(ws.cell(r, 5).value)
        c6 = _cell_str(ws.cell(r, 6).value)

        daly_both = to_num(ws.cell(r, 7).value)
        daly_male = to_num(ws.cell(r, 8).value)
        daly_female = to_num(ws.cell(r, 9).value)

        node = None
        level = None

        if c3 and not sub_pat.match(c3) and c4 is None and c5 is None and c6 is None:
            lvl0_main = c3
            lvl0_sub = None
            lvl1 = None
            lvl2 = None
            node = lvl0_main
            level = 0
        elif c3 and sub_pat.match(c3) and c4:
            lvl0_sub = c4
            lvl1 = None
            lvl2 = None
            node = lvl0_sub
            level = 1
        elif c4 and num_pat.match(c4) and c5:
            lvl1 = c5
            lvl2 = None
            node = lvl1
            level = 2
        elif c5 and leaf_pat.match(c5) and c6:
            lvl2 = c6
            node = lvl2
            level = 3
        else:
            continue

        row = {
            "region": region,
            "year": year,
            "sheet": sheet_name,
            "code": code,
            "level": level,
            "node": node,
            "level0_main": lvl0_main,
            "level0_sub": lvl0_sub,
            "level1": lvl1,
            "level2": lvl2,
            "daly_both_total": daly_both,
            "daly_male_total": daly_male,
            "daly_female_total": daly_female,
        }

        for tag, col in male_age_cols:
            row[f"daly_male_{tag}"] = to_num(ws.cell(r, col).value)
        for tag, col in female_age_cols:
            row[f"daly_female_{tag}"] = to_num(ws.cell(r, col).value)

        out.append(row)

    df = pd.DataFrame(out)
    df["path"] = df[["level0_main", "level0_sub", "level1", "level2"]].astype(object).agg(
        lambda x: " > ".join([v for v in x if isinstance(v, str) and v.strip()]),
        axis=1,
    )
    return df

# %%
xlsx_bytes = download_ghe_xlsx()
tax_2021 = parse_global_sheet_to_taxonomy(xlsx_bytes, "Global 2021")
tax_2021.head()
# Out:
#    region  year        sheet  code  level  \
# 0  Global  2021  Global 2021     0      0
# 1  Global  2021  Global 2021    10      0
# 2  Global  2021  Global 2021    20      1
# 3  Global  2021  Global 2021    30      2
# 4  Global  2021  Global 2021    40      2
#
#                                                 node  \
# 0                                         All Causes
# 1  Communicable, maternal, perinatal and nutritio...
# 2                  Infectious and parasitic diseases
# 3                                       Tuberculosis
# 4                                 STDs excluding HIV
#
#                                          level0_main  \
# 0                                         All Causes
# 1  Communicable, maternal, perinatal and nutritio...
# 2  Communicable, maternal, perinatal and nutritio...
# 3  Communicable, maternal, perinatal and nutritio...
# 4  Communicable, maternal, perinatal and nutritio...
#
#                           level0_sub              level1 level2  ...  \
# 0                               None                None   None  ...
# 1                               None                None   None  ...
# 2  Infectious and parasitic diseases                None   None  ...
# 3  Infectious and parasitic diseases        Tuberculosis   None  ...
# 4  Infectious and parasitic diseases  STDs excluding HIV   None  ...
#
#    daly_male_70_plus  daly_female_0_28_days  daly_female_1_59_months  \
# 0       2.917125e+08           9.823325e+07             1.244504e+08
# 1       5.307556e+07           8.734841e+07             9.439322e+07
# 2       8.672585e+06           4.659805e+06             5.905820e+07
# 3       3.757638e+06           5.459553e+01             5.576674e+06
# 4       1.968129e+04           1.869393e+06             7.359206e+05
#
#    daly_female_5_14  daly_female_15_29  daly_female_30_49  daly_female_50_59  \
# 0      6.520948e+07       1.429846e+08       2.700881e+08       1.860011e+08
# 1      2.717642e+07       4.034541e+07       6.274173e+07       3.114981e+07
# 2      1.463574e+07       1.447188e+07       2.167112e+07       9.712355e+06
# 3      1.458158e+06       3.330256e+06       5.390538e+06       3.481570e+06
# 4      3.730480e+04       2.234408e+05       4.822917e+05       1.186005e+05
#
#    daly_female_60_69  daly_female_70_plus  \
# 0       2.084319e+08         3.138755e+08
# 1       3.508791e+07         4.784674e+07
# 2       8.049872e+06         9.888397e+06
# 3       2.912588e+06         2.858887e+06
# 4       5.829581e+04         4.600198e+04
#
#                                                 path
# 0                                         All Causes
# 1  Communicable, maternal, perinatal and nutritio...
# 2  Communicable, maternal, perinatal and nutritio...
# 3  Communicable, maternal, perinatal and nutritio...
# 4  Communicable, maternal, perinatal and nutritio...
#
# [5 rows x 30 columns]

# %%
gut_terms = [
    "diarr", "gastro", "enter", "intestin", "bowel", "crohn", "colitis", "ibd",
    "ulcer", "celiac", "coeliac", "colon", "rect", "append",
    "liver", "hepat", "cirrhos", "pancrea", "gall", "bile", "cholang",
    "stomach", "gastric", "esoph", "oesoph",
]
pat = re.compile("|".join(gut_terms), flags=re.IGNORECASE)

gut_tax = tax_2021[tax_2021["path"].str.contains(pat, na=False)].copy()
gut_tax.sort_values("daly_both_total", ascending=False).head(50)
# Out:
#      region  year        sheet  code  level  \
# 12   Global  2021  Global 2021   110      2
# 158  Global  2021  Global 2021  1230      2
# 71   Global  2021  Global 2021   650      2
# 70   Global  2021  Global 2021   640      2
# 138  Global  2021  Global 2021  1050      2
# 72   Global  2021  Global 2021   660      2
# 69   Global  2021  Global 2021   630      2
# 161  Global  2021  Global 2021  1233      3
# 159  Global  2021  Global 2021  1231      3
# 77   Global  2021  Global 2021   670      2
# 160  Global  2021  Global 2021  1232      3
# 162  Global  2021  Global 2021  1234      3
# 73   Global  2021  Global 2021   661      3
# 167  Global  2021  Global 2021  1246      2
# 165  Global  2021  Global 2021  1242      2
# 157  Global  2021  Global 2021  1220      2
# 20   Global  2021  Global 2021   185      2
# 168  Global  2021  Global 2021  1248      2
# 91   Global  2021  Global 2021   752      2
# 75   Global  2021  Global 2021   663      3
# 74   Global  2021  Global 2021   662      3
# 39   Global  2021  Global 2021   330      2
# 76   Global  2021  Global 2021   664      3
# 22   Global  2021  Global 2021   190      3
# 21   Global  2021  Global 2021   186      3
# 163  Global  2021  Global 2021  1240      2
# 166  Global  2021  Global 2021  1244      2
# 43   Global  2021  Global 2021   362      3
# 40   Global  2021  Global 2021   340      3
# 23   Global  2021  Global 2021   200      3
# 42   Global  2021  Global 2021   360      3
# 24   Global  2021  Global 2021   205      3
# 41   Global  2021  Global 2021   350      3
#
#                                            node  \
# 12                          Diarrhoeal diseases
# 158                      Cirrhosis of the liver
# 71                     Colon and rectum cancers
# 70                               Stomach cancer
# 138               Uncorrected refractive errors
# 72                                 Liver cancer
# 69                            Oesophagus cancer
# 161                Cirrhosis due to alcohol use
# 159                Cirrhosis due to hepatitis B
# 77                              Pancreas cancer
# 160                Cirrhosis due to hepatitis C
# 162                       Other liver cirrhosis
# 73        Liver cancer secondary to hepatitis B
# 167            Gallbladder and biliary diseases
# 165  Paralytic ileus and intestinal obstruction
# 157                        Peptic ulcer disease
# 20                                    Hepatitis
# 168                                Pancreatitis
# 91         Gallbladder and biliary tract cancer
# 75        Liver cancer secondary to alcohol use
# 74        Liver cancer secondary to hepatitis C
# 39               Intestinal nematode infections
# 76                           Other liver cancer
# 22                            Acute hepatitis B
# 21                            Acute hepatitis A
# 163                                Appendicitis
# 166                  Inflammatory bowel disease
# 43                        Food-borne trematodes
# 40                                   Ascariasis
# 23                            Acute hepatitis C
# 42                             Hookworm disease
# 24                            Acute hepatitis E
# 41                                 Trichuriasis
#
#                                            level0_main  \
# 12   Communicable, maternal, perinatal and nutritio...
# 158                           Noncommunicable diseases
# 71                            Noncommunicable diseases
# 70                            Noncommunicable diseases
# 138                           Noncommunicable diseases
# 72                            Noncommunicable diseases
# 69                            Noncommunicable diseases
# 161                           Noncommunicable diseases
# 159                           Noncommunicable diseases
# 77                            Noncommunicable diseases
# 160                           Noncommunicable diseases
# 162                           Noncommunicable diseases
# 73                            Noncommunicable diseases
# 167                           Noncommunicable diseases
# 165                           Noncommunicable diseases
# 157                           Noncommunicable diseases
# 20   Communicable, maternal, perinatal and nutritio...
# 168                           Noncommunicable diseases
# 91                            Noncommunicable diseases
# 75                            Noncommunicable diseases
# 74                            Noncommunicable diseases
# 39   Communicable, maternal, perinatal and nutritio...
# 76                            Noncommunicable diseases
# 22   Communicable, maternal, perinatal and nutritio...
# 21   Communicable, maternal, perinatal and nutritio...
# 163                           Noncommunicable diseases
# 166                           Noncommunicable diseases
# 43   Communicable, maternal, perinatal and nutritio...
# 40   Communicable, maternal, perinatal and nutritio...
# 23   Communicable, maternal, perinatal and nutritio...
# 42   Communicable, maternal, perinatal and nutritio...
# 24   Communicable, maternal, perinatal and nutritio...
# 41   Communicable, maternal, perinatal and nutritio...
#
#                             level0_sub  \
# 12   Infectious and parasitic diseases
# 158                 Digestive diseases
# 71                 Malignant neoplasms
# 70                 Malignant neoplasms
# 138               Sense organ diseases
# 72                 Malignant neoplasms
# 69                 Malignant neoplasms
# 161                 Digestive diseases
# 159                 Digestive diseases
# 77                 Malignant neoplasms
# 160                 Digestive diseases
# 162                 Digestive diseases
# 73                 Malignant neoplasms
# 167                 Digestive diseases
# 165                 Digestive diseases
# 157                 Digestive diseases
# 20   Infectious and parasitic diseases
# 168                 Digestive diseases
# 91                 Malignant neoplasms
# 75                 Malignant neoplasms
# 74                 Malignant neoplasms
# 39   Infectious and parasitic diseases
# 76                 Malignant neoplasms
# 22   Infectious and parasitic diseases
# 21   Infectious and parasitic diseases
# 163                 Digestive diseases
# 166                 Digestive diseases
# 43   Infectious and parasitic diseases
# 40   Infectious and parasitic diseases
# 23   Infectious and parasitic diseases
# 42   Infectious and parasitic diseases
# 24   Infectious and parasitic diseases
# 41   Infectious and parasitic diseases
#
#                                          level1  \
# 12                          Diarrhoeal diseases
# 158                      Cirrhosis of the liver
# 71                     Colon and rectum cancers
# 70                               Stomach cancer
# 138               Uncorrected refractive errors
# 72                                 Liver cancer
# 69                            Oesophagus cancer
# 161                      Cirrhosis of the liver
# 159                      Cirrhosis of the liver
# 77                              Pancreas cancer
# 160                      Cirrhosis of the liver
# 162                      Cirrhosis of the liver
# 73                                 Liver cancer
# 167            Gallbladder and biliary diseases
# 165  Paralytic ileus and intestinal obstruction
# 157                        Peptic ulcer disease
# 20                                    Hepatitis
# 168                                Pancreatitis
# 91         Gallbladder and biliary tract cancer
# 75                                 Liver cancer
# 74                                 Liver cancer
# 39               Intestinal nematode infections
# 76                                 Liver cancer
# 22                                    Hepatitis
# 21                                    Hepatitis
# 163                                Appendicitis
# 166                  Inflammatory bowel disease
# 43               Intestinal nematode infections
# 40               Intestinal nematode infections
# 23                                    Hepatitis
# 42               Intestinal nematode infections
# 24                                    Hepatitis
# 41               Intestinal nematode infections
#
#                                     level2  ...  daly_male_70_plus  \
# 12                                    None  ...       2.580701e+06
# 74        4.511949e+05         5.916479e+05
# 39        6.958397e+04         5.267095e+04
# 76        3.098526e+05         3.371581e+05
# 22        8.120603e+04         5.326896e+04
# 21        4.107324e+04         3.968107e+04
# 163       6.792967e+04         6.588418e+04
# 166       1.061945e+05         1.462874e+05
# 43        5.287333e+04         4.186654e+04
# 40        6.480231e+03         4.381793e+03
# 23        4.427927e+04         4.608403e+04
# 42        8.136833e+03         5.376986e+03
# 24        4.554676e+03         4.722619e+03
# 41        2.093576e+03         1.045623e+03
#
#                                                   path
# 12   Communicable, maternal, perinatal and nutritio...
# 158  Noncommunicable diseases > Digestive diseases ...
# 71   Noncommunicable diseases > Malignant neoplasms...
# 70   Noncommunicable diseases > Malignant neoplasms...
# 138  Noncommunicable diseases > Sense organ disease...
# 72   Noncommunicable diseases > Malignant neoplasms...
# 69   Noncommunicable diseases > Malignant neoplasms...
# 161  Noncommunicable diseases > Digestive diseases ...
# 159  Noncommunicable diseases > Digestive diseases ...
# 77   Noncommunicable diseases > Malignant neoplasms...
# 160  Noncommunicable diseases > Digestive diseases ...
# 162  Noncommunicable diseases > Digestive diseases ...
# 73   Noncommunicable diseases > Malignant neoplasms...
# 167  Noncommunicable diseases > Digestive diseases ...
# 165  Noncommunicable diseases > Digestive diseases ...
# 157  Noncommunicable diseases > Digestive diseases ...
# 20   Communicable, maternal, perinatal and nutritio...
# 168  Noncommunicable diseases > Digestive diseases ...
# 91   Noncommunicable diseases > Malignant neoplasms...
# 75   Noncommunicable diseases > Malignant neoplasms...
# 74   Noncommunicable diseases > Malignant neoplasms...
# 39   Communicable, maternal, perinatal and nutritio...
# 76   Noncommunicable diseases > Malignant neoplasms...
# 22   Communicable, maternal, perinatal and nutritio...
# 21   Communicable, maternal, perinatal and nutritio...
# 163  Noncommunicable diseases > Digestive diseases ...
# 166  Noncommunicable diseases > Digestive diseases ...
# 43   Communicable, maternal, perinatal and nutritio...
# 40   Communicable, maternal, perinatal and nutritio...
# 23   Communicable, maternal, perinatal and nutritio...
# 42   Communicable, maternal, perinatal and nutritio...
# 24   Communicable, maternal, perinatal and nutritio...
# 41   Communicable, maternal, perinatal and nutritio...
#
# [33 rows x 30 columns]

# %%
import re
import pandas as pd

df = tax_2021.copy()

df["node_s"] = df["node"].astype(str)
df["path_s"] = df["path"].astype(str)

include = [
    "diarr", "inflammatory bowel", "crohn", "ulcerative colitis", "ibd",
    "colon and rectum", "colon cancer", "rectum cancer",
    "stomach cancer", "oesophagus cancer", "esophagus cancer",
    "appendicitis", "peptic ulcer", "ileus", "intestinal obstruction",
    "gastro", "enter", "intestin", "bowel"
]

exclude = [
    "liver", "hepat", "cirrhos",
    "pancrea",
    "gallbladder", "biliary", "bile", "cholang"
]

inc_pat = re.compile("|".join(include), flags=re.IGNORECASE)
exc_pat = re.compile("|".join(exclude), flags=re.IGNORECASE)

mask_inc = df["node_s"].str.contains(inc_pat, na=False) | df["path_s"].str.contains(inc_pat, na=False)
mask_exc = df["node_s"].str.contains(exc_pat, na=False) | df["path_s"].str.contains(exc_pat, na=False)

gut_tax = df[mask_inc & ~mask_exc].copy()
gut_tax
# Out:
#      region  year        sheet  code  level  \
# 12   Global  2021  Global 2021   110      2
# 39   Global  2021  Global 2021   330      2
# 40   Global  2021  Global 2021   340      3
# 41   Global  2021  Global 2021   350      3
# 42   Global  2021  Global 2021   360      3
# 43   Global  2021  Global 2021   362      3
# 69   Global  2021  Global 2021   630      2
# 70   Global  2021  Global 2021   640      2
# 71   Global  2021  Global 2021   650      2
# 157  Global  2021  Global 2021  1220      2
# 163  Global  2021  Global 2021  1240      2
# 165  Global  2021  Global 2021  1242      2
# 166  Global  2021  Global 2021  1244      2
#
#                                            node  \
# 12                          Diarrhoeal diseases
# 39               Intestinal nematode infections
# 40                                   Ascariasis
# 41                                 Trichuriasis
# 42                             Hookworm disease
# 43                        Food-borne trematodes
# 69                            Oesophagus cancer
# 70                               Stomach cancer
# 71                     Colon and rectum cancers
# 157                        Peptic ulcer disease
# 163                                Appendicitis
# 165  Paralytic ileus and intestinal obstruction
# 166                  Inflammatory bowel disease
#
#                                            level0_main  \
# 12   Communicable, maternal, perinatal and nutritio...
# 39   Communicable, maternal, perinatal and nutritio...
# 40   Communicable, maternal, perinatal and nutritio...
# 41   Communicable, maternal, perinatal and nutritio...
# 42   Communicable, maternal, perinatal and nutritio...
# 43   Communicable, maternal, perinatal and nutritio...
# 69                            Noncommunicable diseases
# 70                            Noncommunicable diseases
# 71                            Noncommunicable diseases
# 157                           Noncommunicable diseases
# 163                           Noncommunicable diseases
# 165                           Noncommunicable diseases
# 166                           Noncommunicable diseases
#
#                             level0_sub  \
# 12   Infectious and parasitic diseases
# 39   Infectious and parasitic diseases
# 40   Infectious and parasitic diseases
# 41   Infectious and parasitic diseases
# 42   Infectious and parasitic diseases
# 43   Infectious and parasitic diseases
# 69                 Malignant neoplasms
# 70                 Malignant neoplasms
# 71                 Malignant neoplasms
# 157                 Digestive diseases
# 163                 Digestive diseases
# 165                 Digestive diseases
# 166                 Digestive diseases
#
#                                          level1                 level2  ...  \
# 12                          Diarrhoeal diseases                   None  ...
# 39               Intestinal nematode infections                   None  ...
# 40               Intestinal nematode infections             Ascariasis  ...
# 41               Intestinal nematode infections           Trichuriasis  ...
# 42               Intestinal nematode infections       Hookworm disease  ...
# 43               Intestinal nematode infections  Food-borne trematodes  ...
# 69                            Oesophagus cancer                   None  ...
# 70                               Stomach cancer                   None  ...
# 71                     Colon and rectum cancers                   None  ...
# 157                        Peptic ulcer disease                   None  ...
# 163                                Appendicitis                   None  ...
# 165  Paralytic ileus and intestinal obstruction                   None  ...
# 166                  Inflammatory bowel disease                   None  ...
#
#      daly_female_1_59_months  daly_female_5_14  daly_female_15_29  \
# 12              1.657392e+07      3.183190e+06       2.209743e+06
# 39              1.802604e+05      2.584474e+05       1.982501e+05
# 40              1.364655e+05      1.092340e+05       4.432677e+04
# 41              4.726444e+03      2.636028e+04       3.865861e+04
# 42              3.853643e+04      1.136850e+05       7.452047e+04
# 43              5.320459e+02      9.168122e+03       4.074425e+04
# 166  Noncommunicable diseases > Digestive diseases ...
#
# [13 rows x 32 columns]

# %%
gut_cause = (
    gut_tax
    .dropna(subset=["daly_both_total"])
    .sort_values("daly_both_total", ascending=False)
    .drop_duplicates(subset=["code"])
    .copy()
)

gut_cause[["code", "node", "level", "level1", "level2", "daly_both_total"]]
# Out:
#      code                                        node  level  \
# 12    110                         Diarrhoeal diseases      2
# 71    650                    Colon and rectum cancers      2
# 70    640                              Stomach cancer      2
# 69    630                           Oesophagus cancer      2
# 165  1242  Paralytic ileus and intestinal obstruction      2
# 157  1220                        Peptic ulcer disease      2
# 39    330              Intestinal nematode infections      2
# 163  1240                                Appendicitis      2
# 166  1244                  Inflammatory bowel disease      2
# 43    362                       Food-borne trematodes      3
# 40    340                                  Ascariasis      3
# 42    360                            Hookworm disease      3
# 41    350                                Trichuriasis      3
#
#                                          level1                 level2  \
# 12                          Diarrhoeal diseases                   None
# 71                     Colon and rectum cancers                   None
# 70                               Stomach cancer                   None
# 69                            Oesophagus cancer                   None
# 165  Paralytic ileus and intestinal obstruction                   None
# 157                        Peptic ulcer disease                   None
# 39               Intestinal nematode infections                   None
# 163                                Appendicitis                   None
# 166                  Inflammatory bowel disease                   None
# 43               Intestinal nematode infections  Food-borne trematodes
# 40               Intestinal nematode infections             Ascariasis
# 42               Intestinal nematode infections       Hookworm disease
# 41               Intestinal nematode infections           Trichuriasis
#
#      daly_both_total
# 12      6.974344e+07
# 71      2.404774e+07
# 70      2.202943e+07
# 69      1.366366e+07
# 165     6.657518e+06
# 157     6.320257e+06
# 39      2.307107e+06
# 163     1.325560e+06
# 166     1.296912e+06
# 43      8.938607e+05
# 40      6.838845e+05
# 42      5.349383e+05
# 41      1.944234e+05

# %%
plot_df = gut_cause.sort_values("daly_both_total", ascending=False).head(25).iloc[::-1]

plt.figure(figsize=(9, 7.5))
plt.barh(plot_df["node"], plot_df["daly_both_total"])
plt.xlabel("DALYs (Global 2021, both sexes)")
plt.ylabel("Cause")
plt.title("GI tract DALYs")
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd

gwas = pd.read_csv(gwas_path, sep="\t")

for c in ["Coefficient", "Coefficient_std_error", "Coefficient_P_value", "bonf_p", "fdr_p"]:
    if c in gwas.columns:
        gwas[c] = pd.to_numeric(gwas[c], errors="coerce")

gwas["z"] = gwas["Coefficient"] / gwas["Coefficient_std_error"]

if "fdr_p" in gwas.columns:
    gwas["neglog10_fdr"] = -np.log10(np.clip(gwas["fdr_p"].astype(float), 1e-300, 1.0))
else:
    gwas["neglog10_fdr"] = np.nan

if "fdr_significant" in gwas.columns:
    sig_mask = gwas["fdr_significant"].astype(bool)
else:
    sig_mask = gwas["fdr_p"] <= 0.1

x = gwas[sig_mask].copy()

vuln_ct = (
    x.groupby(["gwas_disease", "gwas_disease_id", "celltype"], dropna=False)["z"]
    .apply(lambda s: float(np.nansum(np.abs(s))))
    .reset_index(name="vulnerability")
)

vuln_dis = (
    vuln_ct.groupby(["gwas_disease", "gwas_disease_id"], dropna=False)["vulnerability"]
    .sum()
    .reset_index()
    .sort_values("vulnerability", ascending=False)
)

vuln_ct.head()
# Out:
#         gwas_disease gwas_disease_id             celltype  vulnerability
# 0  colorectal_cancer   MONDO_0005575          Colonocytes       2.673865
# 1  colorectal_cancer   MONDO_0005575    Colonocytes_BEST4       2.684450
# 2  colorectal_cancer   MONDO_0005575  Colonocytes_Laminin       3.461831
# 3  colorectal_cancer   MONDO_0005575     Colonocytes_Late       3.224484
# 4  colorectal_cancer   MONDO_0005575          Enterocytes       3.338204

# %%
def norm(s):
    return str(s).lower().strip()

who_nodes = gut_cause[["node", "daly_both_total"]].copy()
who_nodes["node_norm"] = who_nodes["node"].map(norm)

override = {
    "crohns_disease": "Inflammatory bowel disease",
    "crohn's disease": "Inflammatory bowel disease",
    "ulcerative_colitis": "Inflammatory bowel disease",
    "ulcerative colitis": "Inflammatory bowel disease",
    "inflammatory_bowel_disease": "Inflammatory bowel disease",
    "ibd": "Inflammatory bowel disease",
    "colorectal cancer": "Colon and rectum cancers",
    "colon cancer": "Colon and rectum cancers",
    "rectal cancer": "Colon and rectum cancers",
    "diarrhea": "Diarrhoeal diseases",
    "diarrhoea": "Diarrhoeal diseases",
}

def map_gwas_to_who(gwas_name):
    s = norm(gwas_name)
    if s in override:
        return override[s]
    if "crohn" in s or "ulcerative" in s or "colitis" in s or "ibd" in s:
        return "Inflammatory bowel disease"
    if "colorect" in s or ("colon" in s and "cancer" in s) or ("rect" in s and "cancer" in s):
        return "Colon and rectum cancers"
    if "stomach" in s and "cancer" in s:
        return "Stomach cancer"
    if ("oesoph" in s or "esoph" in s) and "cancer" in s:
        return "Oesophagus cancer"
    if "diarr" in s:
        return "Diarrhoeal diseases"
    if "appendic" in s:
        return "Appendicitis"
    if "ulcer" in s:
        return "Peptic ulcer disease"
    if "ileus" in s or "obstruction" in s:
        return "Paralytic ileus and intestinal obstruction"
    if "nematode" in s or "helminth" in s or "hookworm" in s or "ascar" in s or "trichur" in s:
        return "Intestinal nematode infections"
    return None

vmap = vuln_dis.copy()
vmap["who_cause"] = vmap["gwas_disease"].map(map_gwas_to_who)

merged = vmap.merge(
    who_nodes.rename(columns={"node": "who_cause", "daly_both_total": "daly"}),
    on="who_cause",
    how="left",
)

merged.sort_values("vulnerability", ascending=False).head(30)
# Out:
#                  gwas_disease gwas_disease_id  vulnerability  \
# 0  inflammatory_bowel_disease     EFO_0003767     136.567095
# 1              crohns_disease     EFO_0000384     118.515661
# 2          ulcerative_colitis     EFO_0000729      82.957471
# 3           colorectal_cancer   MONDO_0005575      43.383627
# 4         colorectal_neoplasm     EFO_0004142       6.431236
# 5         congenital_diarrhea   MONDO_0000824       6.431236
# 6           diarrheal_disease   MONDO_0001673       6.431236
# 7    irritable_bowel_syndrome     EFO_0000555       6.211924
#
#                     who_cause          daly                   node_norm
# 0  Inflammatory bowel disease  1.296912e+06  inflammatory bowel disease
# 1  Inflammatory bowel disease  1.296912e+06  inflammatory bowel disease
# 2  Inflammatory bowel disease  1.296912e+06  inflammatory bowel disease
# 3    Colon and rectum cancers  2.404774e+07    colon and rectum cancers
# 4    Colon and rectum cancers  2.404774e+07    colon and rectum cancers
# 5         Diarrhoeal diseases  6.974344e+07         diarrhoeal diseases
# 6         Diarrhoeal diseases  6.974344e+07         diarrhoeal diseases
# 7                        None           NaN                         NaN

# %%
cause_to_color = {}
unique_causes = [c for c in merged["who_cause"].dropna().unique().tolist()]

for i, c in enumerate(unique_causes):
    cause_to_color[c] = palette[i % len(palette)]

top_celltypes_per_disease = 15

mapped_diseases = merged.dropna(subset=["who_cause"]).sort_values("vulnerability", ascending=False)
mapped_diseases = mapped_diseases["gwas_disease"].tolist()

for dis in mapped_diseases:
    who_cause = merged.loc[merged["gwas_disease"] == dis, "who_cause"].iloc[0]
    color = cause_to_color.get(who_cause, "#666666")

    sub = vuln_ct[vuln_ct["gwas_disease"] == dis].sort_values("vulnerability", ascending=False).head(top_celltypes_per_disease)
    if sub.shape[0] == 0:
        continue

    sub = sub.iloc[::-1].copy()

    plt.figure(figsize=(8.6, 5.6))
    plt.barh(sub["celltype"], sub["vulnerability"], color=color, alpha=0.9)
    plt.xlabel("Cell type vulnerability (sum abs z across significant hits)")
    plt.ylabel("")
    plt.title(f"{dis}  |  WHO: {who_cause}")
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(7.8, 6.2))

for who_cause, grp in m.groupby("who_cause"):
    plt.scatter(grp["log10_daly"], grp["vulnerability"], s=70, alpha=0.9, color=cause_to_color.get(who_cause, "#666666"), label=who_cause)

plt.xlabel("log10 DALYs (WHO Global 2021, both sexes)")
plt.ylabel("Disease vulnerability (sum over cell types of sum abs z)")
plt.title("Global gut disease burden vs cell type genetic vulnerability")
plt.legend(frameon=False, fontsize=9)
plt.tight_layout()
plt.show()

# %%
mapped = vuln_ct.merge(
    merged[["gwas_disease", "who_cause"]],
    on="gwas_disease",
    how="inner",
)

cause_ct = (
    mapped.dropna(subset=["who_cause"])
    .groupby(["who_cause", "celltype"], dropna=False)["vulnerability"]
    .sum()
    .reset_index()
)

for who_cause in sorted(cause_ct["who_cause"].dropna().astype(str).unique().tolist()):
    sub = (
        cause_ct[cause_ct["who_cause"] == who_cause]
        .sort_values("vulnerability", ascending=False)
        .head(15)
        .iloc[::-1]
        .copy()
    )

    plt.figure(figsize=(8.6, 5.6))
    plt.barh(sub["celltype"], sub["vulnerability"], color=cause_to_color.get(who_cause, "#666666"), alpha=0.9)
    plt.xlabel("Pooled vulnerability (sum across GWAS traits mapped to this WHO cause)")
    plt.ylabel("")
    plt.title(f"Top cell types for WHO cause: {who_cause}")
    plt.tight_layout()
    plt.show()

# %%
overall_ct = (
    mapped.dropna(subset=["who_cause"])
    .groupby("celltype", dropna=False)["vulnerability"]
    .sum()
    .reset_index()
    .sort_values("vulnerability", ascending=False)
)

top_n = 25
sub = overall_ct.head(top_n).iloc[::-1].copy()

plt.figure(figsize=(8.6, 7.2))
plt.barh(sub["celltype"], sub["vulnerability"], color="#444444", alpha=0.9)
plt.xlabel("Total gut vulnerability (sum across mapped gut diseases)")
plt.ylabel("")
plt.title("Most genetically vulnerable cell types across gut diseases")
plt.tight_layout()
plt.show()
