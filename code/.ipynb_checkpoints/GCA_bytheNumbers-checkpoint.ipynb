# %%
import pandas as pd
import numpy as np
from plotnine import *
from anndata import read_h5ad

# %%
adata = read_h5ad('/Users/kylekimler/Projects/GCA/meta_datasets/healthy_concat_qc_CELLxGENE.h5ad')

meta = adata.obs

# %%
meta['cell_id'] = meta.index

# %%
df_dataset = pd.read_csv('/Users/kylekimler/gitHub/hca-gut-atlas-extension/src/harmonized_metadata/concatenated_dataset_metadata.csv').drop(columns=['index'])
df_sample = pd.read_csv('/Users/kylekimler/gitHub/hca-gut-atlas-extension/src/harmonized_metadata/concatenated_sample_metadata.csv').drop(columns=['index'])
df_donor = pd.read_csv('/Users/kylekimler/gitHub/hca-gut-atlas-extension/src/harmonized_metadata/concatenated_donor_metadata.csv').drop(columns=['index'])

# df_dataset.shape
df_sample.shape
# df_donor.shape
# Out:
# (770, 42)

# %%
df_sample['age_range']
# Out:
# 0      60-70
# 1      60-70
# 2      60-70
# 3      60-70
# 4      70-80
#        ...
# 765      0-1
# 766      0-1
# 767      0-1
# 768      0-1
# 769      0-1
# Name: age_range, Length: 770, dtype: object

# %%
# Assuming df_donor is your DataFrame
# Convert the entire column to string first, handling NaN appropriately
df_sample['age_range'] = df_sample['age_range'].astype(str)

def fix_age_range(age_range):
    if '-' in age_range:  # Check if the hyphen is in the string
        ages = age_range.split('-')
        if len(ages) == 2:
            # Adjust the upper age by subtracting 1
            upper_age = int(ages[1]) - 1
            # Return the corrected age range
            return f"{ages[0]}-{upper_age}"
    return age_range  # Return original if not in the expected format

# Apply the function to the 'age_range' column
df_sample['age_range'] = df_sample['age_range'].apply(fix_age_range)

# %%
summary_df = meta.groupby('title').agg(
    total_samples=('sample_id', 'nunique'),
    total_donors=('donor_id', 'nunique'),
    total_cells=('cell_id', 'size')  # Assuming 'cell_id' is the index or a column in the .obs attribute
).reset_index()

# %%
totals_df = summary_df
totals_df['title'] = 1

# %%
df_dataset['title']
# Out:
# 0                                  Hickey2023
# 1                                   James2020
# 2                                  Jaeger2021
# 3                                   Huang2019
# 4                             He2020GenomeBio
# 5                                    Kong2023
# 6                                   Zheng2024
# 7                                 Kinchen2018
# 8                                    Wang2020
# 9                         KarakashevaHelmsley
# 10                             Maddipatla2023
# 11                                Nowicki2021
# 12                                 Martin2019
# 13                                     Yu2021
# 14        Lamina propria CD45+CD3-CD19-HLADR+
# 15         Submucosa Epcam-CD235ab-CD45-CD31-
# 16    Lamina propria Epcam-CD235ab-CD45-CD31-
# 17         Lamina propria Epcam-CD235ab-CD45-
# 18                               BasuHelmsley
# 19                                    Lee2020
# 20                             Elmentaite2021
# 21                                  Krzak2023
# 22                                  Luoma2020
# 23                              Dominguez2022
# 24                                 Boland2020
# 25                                  Uzzan2022
# 26                                 Parikh2019
# 27                                  Egozi2023
# Name: title, dtype: object

# %%
title_count = melted_df[melted_df['Category'] == 'title'].shape[0]  # Count all entries with 'title'
other_metrics = melted_df[melted_df['Category'] != 'title'].groupby('Category').sum().reset_index()

# Creating a new summary dataframe
summary_df = pd.DataFrame({
    'Category': ['title'] + other_metrics['Category'].tolist(),
    'Count': [title_count] + other_metrics['Count'].tolist()
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 title_count = melted_df[melted_df['Category'] == 'title'].shape[0]  # Count all entries with 'title'
#       2 other_metrics = melted_df[melted_df['Category'] != 'title'].groupby('Category').sum().reset_index()
#       4 # Creating a new summary dataframe
#
# NameError: name 'melted_df' is not defined

# %%
p = (ggplot(summary_df, aes(x='Category', y='Count', fill='Category'))
     + geom_bar(stat='identity', position='dodge')
     + geom_text(aes(label='Count'),
                 position=position_dodge(width=0.9),  # Adjust this width as necessary
                 va='bottom', size=8)
     + coord_flip()
     + theme_minimal()
     + labs(title='Summary of Data', y='Total Count', x='Metric')
)
p.show()  # Use show method to display the plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/mapping/evaluation.py:223, in evaluate(aesthetics, data, env)
#     222 try:
# --> 223     new_val = env.eval(col, inner_namespace=data)
#     224 except Exception as e:
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/mapping/_env.py:69, in Environment.eval(self, expr, inner_namespace)
#      68 code = _compile_eval(expr)
# ---> 69 return eval(
#      70     code, {}, StackedLookup([inner_namespace] + self.namespaces)
#      71 )
#
# File <string-expression>:1
#
# NameError: name 'Category' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PlotnineError                             Traceback (most recent call last)
# Cell In[9], line 10
#       1 p = (ggplot(summary_df, aes(x='Category', y='Count', fill='Category'))
#       2      + geom_bar(stat='identity', position='dodge')
#       3      + geom_text(aes(label='Count'),
#    (...)
#       8      + labs(title='Summary of Data', y='Total Count', x='Metric')
#       9 )
# ---> 10 p.show()  # Use show method to display the plot
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:150, in ggplot.show(self)
#     143 def show(self):
#     144     """
#     145     Show plot using the matplotlib backend set by the user
#     146
#     147     Users should prefer this method instead of printing or repring
#     148     the object.
#     149     """
# --> 150     self._display() if is_inline_backend() else self.draw(show=True)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:175, in ggplot._display(self)
#     172     save_format = "png"
#     174 buf = BytesIO()
# --> 175 self.save(buf, format=save_format, verbose=False)
#     176 display_func = get_display_function(format)
#     177 display_func(buf.getvalue())
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:663, in ggplot.save(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     615 def save(
#     616     self,
#     617     filename: Optional[str | Path | BytesIO] = None,
#    (...)
#     626     **kwargs: Any,
#     627 ):
#     628     """
#     629     Save a ggplot object as an image file
#     630
#    (...)
#     661         Additional arguments to pass to matplotlib `savefig()`.
#     662     """
# --> 663     sv = self.save_helper(
#     664         filename=filename,
#     665         format=format,
#     666         path=path,
#     667         width=width,
#     668         height=height,
#     669         units=units,
#     670         dpi=dpi,
#     671         limitsize=limitsize,
#     672         verbose=verbose,
#     673         **kwargs,
#     674     )
#     676     with plot_context(self).rc_context:
#     677         sv.figure.savefig(**sv.kwargs)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:612, in ggplot.save_helper(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     609 if dpi is not None:
#     610     self.theme = self.theme + theme(dpi=dpi)
# --> 612 figure = self.draw(show=False)
#     613 return mpl_save_view(figure, fig_kwargs)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:272, in ggplot.draw(self, show)
#     270 self = deepcopy(self)
#     271 with plot_context(self, show=show):
# --> 272     self._build()
#     274     # setup
#     275     self.figure, self.axs = self.facet.setup(self)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:362, in ggplot._build(self)
#     358 layout.setup(layers, self)
#     360 # Compute aesthetics to produce data with generalised
#     361 # variable names
# --> 362 layers.compute_aesthetics(self)
#     364 # Transform data using all scales
#     365 layers.transform(scales)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/layer.py:457, in Layers.compute_aesthetics(self, plot)
#     455 def compute_aesthetics(self, plot: ggplot):
#     456     for l in self:
# --> 457         l.compute_aesthetics(plot)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/layer.py:260, in layer.compute_aesthetics(self, plot)
#     253 def compute_aesthetics(self, plot: ggplot):
#     254     """
#     255     Return a dataframe where the columns match the aesthetic mappings
#     256
#     257     Transformations like 'factor(cyl)' and other
#     258     expression evaluation are  made in here
#     259     """
# --> 260     evaled = evaluate(self.mapping._starting, self.data, plot.environment)
#     261     evaled_aes = aes(**{str(col): col for col in evaled})
#     262     plot.scales.add_defaults(evaled, evaled_aes)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/mapping/evaluation.py:226, in evaluate(aesthetics, data, env)
#     224 except Exception as e:
#     225     msg = _TPL_EVAL_FAIL.format(ae, col, str(e))
# --> 226     raise PlotnineError(msg) from e
#     228 try:
#     229     evaled[ae] = new_val
#
# PlotnineError: "Could not evaluate the 'x' mapping: 'Category' (original error: name 'Category' is not defined)"

# %%
p = (ggplot(summary_df, aes(x='Category', y='Count', fill='Category'))
     + geom_bar(stat='identity', position='dodge')
     + geom_text(aes(label='Count'),
                 position=position_dodge(width=0.9),  # Adjust this width as necessary
                 va='bottom', size=8)
     + coord_flip()
     + theme_minimal()
     + labs(title='Summary of Data', y='Total Count', x='Metric')
)
p.show()  # Use show method to display the plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/mapping/evaluation.py:223, in evaluate(aesthetics, data, env)
#     222 try:
# --> 223     new_val = env.eval(col, inner_namespace=data)
#     224 except Exception as e:
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/mapping/_env.py:69, in Environment.eval(self, expr, inner_namespace)
#      68 code = _compile_eval(expr)
# ---> 69 return eval(
#      70     code, {}, StackedLookup([inner_namespace] + self.namespaces)
#      71 )
#
# File <string-expression>:1
#
# NameError: name 'Category' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PlotnineError                             Traceback (most recent call last)
# Cell In[10], line 10
#       1 p = (ggplot(summary_df, aes(x='Category', y='Count', fill='Category'))
#       2      + geom_bar(stat='identity', position='dodge')
#       3      + geom_text(aes(label='Count'),
#    (...)
#       8      + labs(title='Summary of Data', y='Total Count', x='Metric')
#       9 )
# ---> 10 p.show()  # Use show method to display the plot
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:150, in ggplot.show(self)
#     143 def show(self):
#     144     """
#     145     Show plot using the matplotlib backend set by the user
#     146
#     147     Users should prefer this method instead of printing or repring
#     148     the object.
#     149     """
# --> 150     self._display() if is_inline_backend() else self.draw(show=True)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:175, in ggplot._display(self)
#     172     save_format = "png"
#     174 buf = BytesIO()
# --> 175 self.save(buf, format=save_format, verbose=False)
#     176 display_func = get_display_function(format)
#     177 display_func(buf.getvalue())
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:663, in ggplot.save(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     615 def save(
#     616     self,
#     617     filename: Optional[str | Path | BytesIO] = None,
#    (...)
#     626     **kwargs: Any,
#     627 ):
#     628     """
#     629     Save a ggplot object as an image file
#     630
#    (...)
#     661         Additional arguments to pass to matplotlib `savefig()`.
#     662     """
# --> 663     sv = self.save_helper(
#     664         filename=filename,
#     665         format=format,
#     666         path=path,
#     667         width=width,
#     668         height=height,
#     669         units=units,
#     670         dpi=dpi,
#     671         limitsize=limitsize,
#     672         verbose=verbose,
#     673         **kwargs,
#     674     )
#     676     with plot_context(self).rc_context:
#     677         sv.figure.savefig(**sv.kwargs)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:612, in ggplot.save_helper(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     609 if dpi is not None:
#     610     self.theme = self.theme + theme(dpi=dpi)
# --> 612 figure = self.draw(show=False)
#     613 return mpl_save_view(figure, fig_kwargs)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:272, in ggplot.draw(self, show)
#     270 self = deepcopy(self)
#     271 with plot_context(self, show=show):
# --> 272     self._build()
#     274     # setup
#     275     self.figure, self.axs = self.facet.setup(self)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:362, in ggplot._build(self)
#     358 layout.setup(layers, self)
#     360 # Compute aesthetics to produce data with generalised
#     361 # variable names
# --> 362 layers.compute_aesthetics(self)
#     364 # Transform data using all scales
#     365 layers.transform(scales)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/layer.py:457, in Layers.compute_aesthetics(self, plot)
#     455 def compute_aesthetics(self, plot: ggplot):
#     456     for l in self:
# --> 457         l.compute_aesthetics(plot)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/layer.py:260, in layer.compute_aesthetics(self, plot)
#     253 def compute_aesthetics(self, plot: ggplot):
#     254     """
#     255     Return a dataframe where the columns match the aesthetic mappings
#     256
#     257     Transformations like 'factor(cyl)' and other
#     258     expression evaluation are  made in here
#     259     """
# --> 260     evaled = evaluate(self.mapping._starting, self.data, plot.environment)
#     261     evaled_aes = aes(**{str(col): col for col in evaled})
#     262     plot.scales.add_defaults(evaled, evaled_aes)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/mapping/evaluation.py:226, in evaluate(aesthetics, data, env)
#     224 except Exception as e:
#     225     msg = _TPL_EVAL_FAIL.format(ae, col, str(e))
# --> 226     raise PlotnineError(msg) from e
#     228 try:
#     229     evaled[ae] = new_val
#
# PlotnineError: "Could not evaluate the 'x' mapping: 'Category' (original error: name 'Category' is not defined)"

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1267745 × 16839
#     obs: 'sample_id', 'donor_id', 'title', 'cell_ontology_term_id', 'author_cell_type', 'publication_doi', 'institute', 'contact_email', 'reference_genome', 'gene_annotation_version', 'alignment_software', 'intron_inclusion', 'ambient_count_correction', 'doublet_detection', 'study_pi', 'batch_condition', 'default_embedding', 'comments', 'protocol_url', 'consortia', 'description', 'doi', 'protocl_url', 'organism_ontology_term_id', 'manner_of_death', 'sex_ontology_term_id', 'disease_free_text', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'disease_ontology_term', 'organism', 'disease', 'self_reported_ethnicity_term_id', 'sample_collection_site', 'sample_collection_relative_time_point', 'library_id', 'library_id_repository', 'sample_source', 'sample_collection_method', 'tissue_type', 'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_ontology_term', 'radial_tissue_term', 'sample_preservation_method', 'suspension_type', 'cell_enrichment', 'cell_viability_percentage', 'cell_number_loaded', 'sample_collection_year', 'assay_ontology_term_id', 'assay_ontology_term', 'library_preparation_batch', 'library_sequencing_run', 'sequenced_fragment', 'sequencing_platform', 'is_primary_data', 'development_stage_ontology_term_id', 'age_range', 'sample_collection_time_point', 'n_cells', 'n_genes', 'total_n_reads', 'min_n_reads', 'median_n_reads', 'max_n_reads', 'min_fraction_MT_reads', 'worksheet', 'sample_uniqueness', 'median_fraction_MT_reads', 'max_fraction_MT_reads', 'tissue_free_text', 'tissue', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'leiden_0.3', 'leiden_0.5', 'cell_id'
#     var: 'gene_symbol', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'title'
#     obsm: 'X_scvi', 'X_umap'

# %%
print(*meta['title'].unique())

stacking_values = ['Krzak2023', 'Boland2020']
# Out:
# agace_helmsley BasuHelmsley Maddipatla2023 Hickey2023 dominguez_2022 Kong2023 Luoma2020 Zheng2024 Egozi2023 KarakashevaHelmsley Elmentaite2021 He2020GenomeBio Huang2019 James2020 Kinchen2018 Parikh2019 Uzzan2022 Yu2021

# %%
import pandas as pd
from plotnine import ggplot, aes, geom_bar, coord_flip, facet_wrap, theme_classic, element_text, theme, scale_fill_manual, labs, facet_grid

def create_faceted_bar_graph(df, grouping_var, color_palette, stacking_var=None, stacking_values=None):
    # Compute summary statistics per group
    if stacking_var:
        summary_df = df.groupby([grouping_var, stacking_var], observed=True).agg(
            samples=('sample_id', 'nunique'),
            donors=('donor_id', 'nunique'),
            cells=('cell_id', 'size')  # Assuming 'cell_id' is the index or a column in .obs
        ).reset_index()

        # Melt the DataFrame for easier plotting with facets
        melted_df = summary_df.melt(id_vars=[grouping_var, stacking_var],
                                    var_name='Category', value_name='Count')

        # Add a new column to identify records that fall within the stacking_values or outside it
        melted_df['Group'] = melted_df[stacking_var].apply(lambda x: 'Not in integration' if x in stacking_values else 'In integration')

        # Plot with stacking
        p = (
            ggplot(melted_df, aes(x=grouping_var, y='Count', fill='Group'))
            + geom_bar(stat='identity', position='stack')
            + coord_flip()
            + facet_wrap('~Category', scales='free')
            + theme_classic(base_size=14)
            + theme(
                axis_text_x=element_text(rotation=45, hjust=0.5), 
                axis_text_y=element_text(hjust=1),  # Justify y-axis labels
                legend_position='right', 
                subplots_adjust={'right': 0.85},
                figure_size=(16, 8))  # Adjust figure size for long labels
            + scale_fill_manual(values=color_palette + ['#dddddd'])  # Colors for 'Not in integration'
            + labs(title='Atlas Summary by ' + grouping_var, x=grouping_var, y='Count')
        )

    else:
        summary_df = df.groupby(grouping_var, observed=True).agg(
            samples=('sample_id', 'nunique'),
            donors=('donor_id', 'nunique'),
            cells=('cell_id', 'size')
        ).reset_index()

        # Melt the DataFrame for easier plotting with facets
        melted_df = summary_df.melt(id_vars=[grouping_var],
                                    var_name='Category', value_name='Count')

        # Plot without stacking
        p = (
            ggplot(melted_df, aes(x=grouping_var, y='Count', fill='Category'))
            + geom_bar(stat='identity', position='dodge')
            + coord_flip()
            + facet_wrap('~Category', scales='free')
            + theme_classic(base_size=14)
            + theme(
                axis_text_x=element_text(rotation=45, hjust=0.5), 
                axis_text_y=element_text(hjust=1),  # Justify y-axis labels
                legend_position='right', 
                subplots_adjust={'right': 0.85},
                figure_size=(16, 8))  # Adjust figure size for long labels
            + scale_fill_manual(values=color_palette)
            + labs(title='Atlas Summary by ' + grouping_var, x=grouping_var, y='Count')
        )

    # Remove y-axis tick labels for the second and third facets
    p = p + theme(
        strip_text_y=element_blank()
    )

    return p

# %%
from pandas.api.types import CategoricalDtype

group = 'tissue_ontology_term'

custom_order = reversed(['small_intestine', 'duodenum', 'jejunum', 'ileum', 'caecum', 
                'colon', 'ascending_colon', 'transverse_colon', 'descending_colon', 'sigmoid_colon',
               'rectum', 'gastrointestinal_system_mesentery'])

file_path = f"/Users/kylekimler/Projects/GCA/June2024_meeting/plots/{group}_summary.png"

cat_type = CategoricalDtype(categories=custom_order, ordered=True)

# Convert the DataFrame column to this categorical type
meta[group] = meta[group].astype(cat_type)

# Example usage
plot = create_faceted_bar_graph(meta, 
                                grouping_var=group, 
                                color_palette = ['#172984','#8AD6E8', '#CEF7A0'], 
                                # stacking_var='title', 
                                # stacking_values=['Krzak2023', 'Boland2020']
                               )

wid = 16
hi = 5
print(plot + theme(figure_size=(wid, hi)))
plot.save(filename=file_path, width=wid, height=hi, units='in', dpi=300)
# Out:
# /var/folders/zc/5fly3ly908xb0pd8zy6m6bj80000gn/T/ipykernel_51946/3869688542.py:26: FutureWarning: Using print(plot) to draw and show the plot figure is deprecated and will be removed in a future version. Use plot.show().
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/themes/themeable.py:2419: FutureWarning: You no longer need to use subplots_adjust to make space for the legend or text around the panels. This paramater will be removed in a future version. You can still use 'plot_margin' 'panel_spacing' for your other spacing needs.
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:606: PlotnineWarning: Saving 16 x 5 in image.
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:607: PlotnineWarning: Filename: /Users/kylekimler/Projects/GCA/June2024_meeting/plots/tissue_ontology_term_summary.png
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/themes/themeable.py:2419: FutureWarning: You no longer need to use subplots_adjust to make space for the legend or text around the panels. This paramater will be removed in a future version. You can still use 'plot_margin' 'panel_spacing' for your other spacing needs.

# %%
group = 'radial_tissue_term'

file_path = f"/Users/kylekimler/Projects/GCA/June2024_meeting/plots/{group}_summary.png"

custom_order = reversed(['WM', 'EPI_LP_MUSC', 'EPI_LP', 'EPI', 'LP', 'MUSC', 'SUB'])

file_path = f"/Users/kylekimler/Projects/GCA/June2024_meeting/plots/{group}_summary.png"

cat_type = CategoricalDtype(categories=custom_order, ordered=True)

# Convert the DataFrame column to this categorical type
meta[group] = meta[group].astype(cat_type)


# Example usage
plot = create_faceted_bar_graph(meta, 
                                grouping_var=group, 
                                color_palette = ['#172984','#8AD6E8', '#CEF7A0'], 
                                # stacking_var='title', 
                                # stacking_values=['Krzak2023', 'Boland2020']
                               )

wid = 16
hi = 5
print(plot + theme(figure_size=(wid, hi)))
plot.save(filename=file_path, width=wid, height=hi, units='in', dpi=300)
# Out:
# /var/folders/zc/5fly3ly908xb0pd8zy6m6bj80000gn/T/ipykernel_51946/2175060798.py:25: FutureWarning: Using print(plot) to draw and show the plot figure is deprecated and will be removed in a future version. Use plot.show().
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/themes/themeable.py:2419: FutureWarning: You no longer need to use subplots_adjust to make space for the legend or text around the panels. This paramater will be removed in a future version. You can still use 'plot_margin' 'panel_spacing' for your other spacing needs.
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:606: PlotnineWarning: Saving 16 x 5 in image.
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:607: PlotnineWarning: Filename: /Users/kylekimler/Projects/GCA/June2024_meeting/plots/radial_tissue_term_summary.png
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/themes/themeable.py:2419: FutureWarning: You no longer need to use subplots_adjust to make space for the legend or text around the panels. This paramater will be removed in a future version. You can still use 'plot_margin' 'panel_spacing' for your other spacing needs.

# %%
meta['age_range'] = meta['age_range'].astype(str)

age_ranges = meta['age_range'].unique()
sorted_age_ranges = sorted([x for x in age_ranges if x != 'unknown' and '-' in x], key=lambda x: int(x.split('-')[1]))
age_range_type = CategoricalDtype(categories=sorted_age_ranges, ordered=True)
meta['age_range'] = meta['age_range'].astype(age_range_type)

# %%
group = 'age_range'

file_path = f"/Users/kylekimler/Projects/GCA/June2024_meeting/plots/{group}_summary.png"


# Example usage
plot = create_faceted_bar_graph(meta, 
                                grouping_var=group, 
                                color_palette = ['#172984','#8AD6E8', '#CEF7A0'], 
                                # stacking_var='title', 
                                # stacking_values=['Krzak2023', 'Boland2020']
                               )

wid = 16
hi = 5
print(plot + theme(figure_size=(wid, hi)))
plot.save(filename=file_path, width=wid, height=hi, units='in', dpi=300)
# Out:
# /var/folders/zc/5fly3ly908xb0pd8zy6m6bj80000gn/T/ipykernel_51946/741274398.py:16: FutureWarning: Using print(plot) to draw and show the plot figure is deprecated and will be removed in a future version. Use plot.show().
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/themes/themeable.py:2419: FutureWarning: You no longer need to use subplots_adjust to make space for the legend or text around the panels. This paramater will be removed in a future version. You can still use 'plot_margin' 'panel_spacing' for your other spacing needs.
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:606: PlotnineWarning: Saving 16 x 5 in image.
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:607: PlotnineWarning: Filename: /Users/kylekimler/Projects/GCA/June2024_meeting/plots/age_range_summary.png
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/themes/themeable.py:2419: FutureWarning: You no longer need to use subplots_adjust to make space for the legend or text around the panels. This paramater will be removed in a future version. You can still use 'plot_margin' 'panel_spacing' for your other spacing needs.

# %%
group = 'sample_collection_method'

file_path = f"/Users/kylekimler/Projects/GCA/June2024_meeting/plots/{group}_summary.png"

# Example usage
plot = create_faceted_bar_graph(meta, 
                                grouping_var=group, 
                                color_palette = ['#172984','#8AD6E8', '#CEF7A0'], 
                                # stacking_var='title', 
                                # stacking_values=['Krzak2023', 'Boland2020']
                               )

wid = 16
hi = 5
print(plot + theme(figure_size=(wid, hi)))
plot.save(filename=file_path, width=wid, height=hi, units='in', dpi=300)
# Out:
# /var/folders/zc/5fly3ly908xb0pd8zy6m6bj80000gn/T/ipykernel_51477/590554184.py:15: FutureWarning: Using print(plot) to draw and show the plot figure is deprecated and will be removed in a future version. Use plot.show().
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/themes/themeable.py:2419: FutureWarning: You no longer need to use subplots_adjust to make space for the legend or text around the panels. This paramater will be removed in a future version. You can still use 'plot_margin' 'panel_spacing' for your other spacing needs.
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:606: PlotnineWarning: Saving 16 x 5 in image.
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:607: PlotnineWarning: Filename: /Users/kylekimler/Projects/GCA/June2024_meeting/plots/sample_collection_method_summary.png
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/themes/themeable.py:2419: FutureWarning: You no longer need to use subplots_adjust to make space for the legend or text around the panels. This paramater will be removed in a future version. You can still use 'plot_margin' 'panel_spacing' for your other spacing needs.

# %%
meta['sampled_site_condition']
# Out:
#                                           sample_id                donor_id  \
# cell_id
# AAACCTGAGAAAGTGG-1-0-0-0           P9-SI-LP-CD45neg  P9_Epcam-CD235ab-CD45-
# AAACCTGAGCCACCTG-1-0-0-0           P9-SI-LP-CD45neg  P9_Epcam-CD235ab-CD45-
# AAACCTGAGCGCTCCA-1-0-0-0           P9-SI-LP-CD45neg  P9_Epcam-CD235ab-CD45-
# AAACCTGAGCTCCCAG-1-0-0-0           P9-SI-LP-CD45neg  P9_Epcam-CD235ab-CD45-
# AAACCTGAGCTGAAAT-1-0-0-0           P9-SI-LP-CD45neg  P9_Epcam-CD235ab-CD45-
# ...                                             ...                     ...
# TTTGTCAGTACAGTGG-HT-188-Adult-Duo  HT-188-Adult-Duo                    D158
# TTTGTCAGTATATGAG-HT-188-Adult-Duo  HT-188-Adult-Duo                    D158
# TTTGTCAGTCCAGTAT-HT-188-Adult-Duo  HT-188-Adult-Duo                    D158
# TTTGTCATCATTGCCC-HT-188-Adult-Duo  HT-188-Adult-Duo                    D158
# TTTGTCATCTCGCATC-HT-188-Adult-Duo  HT-188-Adult-Duo                    D158
#
#                                             title cell_ontology_term_id  \
# cell_id
# AAACCTGAGAAAGTGG-1-0-0-0           agace_helmsley               unknown
# AAACCTGAGCCACCTG-1-0-0-0           agace_helmsley               unknown
# AAACCTGAGCGCTCCA-1-0-0-0           agace_helmsley               unknown
# AAACCTGAGCTCCCAG-1-0-0-0           agace_helmsley               unknown
# AAACCTGAGCTGAAAT-1-0-0-0           agace_helmsley               unknown
# ...                                           ...                   ...
# TTTGTCAGTACAGTGG-HT-188-Adult-Duo          Yu2021               unknown
# TTTGTCAGTATATGAG-HT-188-Adult-Duo          Yu2021               unknown
# TTTGTCAGTCCAGTAT-HT-188-Adult-Duo          Yu2021               unknown
# TTTGTCATCATTGCCC-HT-188-Adult-Duo          Yu2021               unknown
# TTTGTCATCTCGCATC-HT-188-Adult-Duo          Yu2021               unknown
#
#                                   author_cell_type  \
# cell_id
# AAACCTGAGAAAGTGG-1-0-0-0
# AAACCTGAGCCACCTG-1-0-0-0
# AAACCTGAGCGCTCCA-1-0-0-0
# AAACCTGAGCTCCCAG-1-0-0-0
# AAACCTGAGCTGAAAT-1-0-0-0
# ...                                            ...
# TTTGTCAGTACAGTGG-HT-188-Adult-Duo       Enterocyte
# TTTGTCAGTATATGAG-HT-188-Adult-Duo    B_plasma_IgA1
# TTTGTCAGTCCAGTAT-HT-188-Adult-Duo               TA
# TTTGTCATCATTGCCC-HT-188-Adult-Duo       Enterocyte
# TTTGTCATCTCGCATC-HT-188-Adult-Duo  Epithelial_stem
#
#                                               publication_doi  institute  \
# cell_id
# AAACCTGAGAAAGTGG-1-0-0-0                                  NaN        DTU
# AAACCTGAGCCACCTG-1-0-0-0                                  NaN        DTU
# AAACCTGAGCGCTCCA-1-0-0-0                                  NaN        DTU
# AAACCTGAGCTCCCAG-1-0-0-0                                  NaN        DTU
# AAACCTGAGCTGAAAT-1-0-0-0                                  NaN        DTU
# ...                                                       ...        ...
# TTTGTCAGTACAGTGG-HT-188-Adult-Duo  10.1016/j.cell.2021.04.028  IHB_Basel
# TTTGTCAGTATATGAG-HT-188-Adult-Duo  10.1016/j.cell.2021.04.028  IHB_Basel
# TTTGTCAGTCCAGTAT-HT-188-Adult-Duo  10.1016/j.cell.2021.04.028  IHB_Basel
# TTTGTCATCATTGCCC-HT-188-Adult-Duo  10.1016/j.cell.2021.04.028  IHB_Basel
# TTTGTCATCTCGCATC-HT-188-Adult-Duo  10.1016/j.cell.2021.04.028  IHB_Basel
#
#                                              contact_email reference_genome  \
# cell_id
# AAACCTGAGAAAGTGG-1-0-0-0           williamagace@sund.ku.dk           GRCh38
# AAACCTGAGCCACCTG-1-0-0-0           williamagace@sund.ku.dk           GRCh38
# AAACCTGAGCGCTCCA-1-0-0-0           williamagace@sund.ku.dk           GRCh38
# AAACCTGAGCTCCCAG-1-0-0-0           williamagace@sund.ku.dk           GRCh38
# AAACCTGAGCTGAAAT-1-0-0-0           williamagace@sund.ku.dk           GRCh38
# ...                                                    ...              ...
# TTTGTCAGTACAGTGG-HT-188-Adult-Duo      grayson.camp@iob.ch    GRCh38-2020-A
# TTTGTCAGTATATGAG-HT-188-Adult-Duo      grayson.camp@iob.ch    GRCh38-2020-A
# TTTGTCAGTCCAGTAT-HT-188-Adult-Duo      grayson.camp@iob.ch    GRCh38-2020-A
# TTTGTCATCATTGCCC-HT-188-Adult-Duo      grayson.camp@iob.ch    GRCh38-2020-A
# TTTGTCATCTCGCATC-HT-188-Adult-Duo      grayson.camp@iob.ch    GRCh38-2020-A
#
#                                   gene_annotation_version  ... pct_counts_mt  \
# cell_id                                                    ...
# AAACCTGAGAAAGTGG-1-0-0-0                           v1.2.0  ...      1.242808
# AAACCTGAGCCACCTG-1-0-0-0                           v1.2.0  ...      4.060434
# AAACCTGAGCGCTCCA-1-0-0-0                           v1.2.0  ...      2.988379
# AAACCTGAGCTCCCAG-1-0-0-0                           v1.2.0  ...      0.993238
# AAACCTGAGCTGAAAT-1-0-0-0                           v1.2.0  ...      1.516793
# ...                                                   ...  ...           ...
# TTTGTCAGTACAGTGG-HT-188-Adult-Duo                     v98  ...     12.269319
# TTTGTCAGTATATGAG-HT-188-Adult-Duo                     v98  ...      1.220887
# TTTGTCAGTCCAGTAT-HT-188-Adult-Duo                     v98  ...      7.368142
# TTTGTCATCATTGCCC-HT-188-Adult-Duo                     v98  ...     28.274429
# TTTGTCATCTCGCATC-HT-188-Adult-Duo                     v98  ...      7.229297
#
#                                   total_counts_ribo log1p_total_counts_ribo  \
# cell_id
# AAACCTGAGAAAGTGG-1-0-0-0                      937.0                6.843750
# AAACCTGAGCCACCTG-1-0-0-0                      569.0                6.345636
# AAACCTGAGCGCTCCA-1-0-0-0                      171.0                5.147494
# AAACCTGAGCTCCCAG-1-0-0-0                      862.0                6.760415
# AAACCTGAGCTGAAAT-1-0-0-0                      505.0                6.226537
# ...                                             ...                     ...
# TTTGTCAGTACAGTGG-HT-188-Adult-Duo            1428.0                7.264730
# TTTGTCAGTATATGAG-HT-188-Adult-Duo            1347.0                7.206378
# TTTGTCAGTCCAGTAT-HT-188-Adult-Duo            2723.0                7.909857
# TTTGTCATCATTGCCC-HT-188-Adult-Duo             164.0                5.105946
# TTTGTCATCTCGCATC-HT-188-Adult-Duo            5364.0                8.587651
#
#                                   pct_counts_ribo total_counts_hb  \
# cell_id
# AAACCTGAGAAAGTGG-1-0-0-0                21.565018             0.0
# AAACCTGAGCCACCTG-1-0-0-0                17.909979             0.0
# AAACCTGAGCGCTCCA-1-0-0-0                 9.463199             0.0
# AAACCTGAGCTCCCAG-1-0-0-0                18.216398             0.0
# AAACCTGAGCTGAAAT-1-0-0-0                10.942578             2.0
# ...                                           ...             ...
# TTTGTCAGTACAGTGG-HT-188-Adult-Duo        7.594532             2.0
# TTTGTCAGTATATGAG-HT-188-Adult-Duo       25.300526             0.0
# TTTGTCAGTCCAGTAT-HT-188-Adult-Duo       36.085342             0.0
# TTTGTCATCATTGCCC-HT-188-Adult-Duo        2.622741             1.0
# TTTGTCATCTCGCATC-HT-188-Adult-Duo       42.426640             0.0
#
#                                   log1p_total_counts_hb pct_counts_hb  \
# cell_id
# AAACCTGAGAAAGTGG-1-0-0-0                       0.000000      0.000000
# AAACCTGAGCCACCTG-1-0-0-0                       0.000000      0.000000
# AAACCTGAGCGCTCCA-1-0-0-0                       0.000000      0.000000
# AAACCTGAGCTCCCAG-1-0-0-0                       0.000000      0.000000
# AAACCTGAGCTGAAAT-1-0-0-0                       1.098612      0.043337
# ...                                                 ...           ...
# TTTGTCAGTACAGTGG-HT-188-Adult-Duo              1.098612      0.010637
# TTTGTCAGTATATGAG-HT-188-Adult-Duo              0.000000      0.000000
# TTTGTCAGTCCAGTAT-HT-188-Adult-Duo              0.000000      0.000000
# TTTGTCATCATTGCCC-HT-188-Adult-Duo              0.693147      0.015992
# TTTGTCATCTCGCATC-HT-188-Adult-Duo              0.000000      0.000000
#
#                                   leiden_0.3  leiden_0.5  \
# cell_id
# AAACCTGAGAAAGTGG-1-0-0-0                   3           2
# AAACCTGAGCCACCTG-1-0-0-0                   6           8
# AAACCTGAGCGCTCCA-1-0-0-0                   6           8
# AAACCTGAGCTCCCAG-1-0-0-0                   3           8
# AAACCTGAGCTGAAAT-1-0-0-0                   6           8
# ...                                      ...         ...
# TTTGTCAGTACAGTGG-HT-188-Adult-Duo          1           0
# TTTGTCAGTATATGAG-HT-188-Adult-Duo          3           2
# TTTGTCAGTCCAGTAT-HT-188-Adult-Duo          9          11
# TTTGTCATCATTGCCC-HT-188-Adult-Duo          1           0
# TTTGTCATCTCGCATC-HT-188-Adult-Duo          9          11
#
#                                                              cell_id
# cell_id
# AAACCTGAGAAAGTGG-1-0-0-0                    AAACCTGAGAAAGTGG-1-0-0-0
# AAACCTGAGCCACCTG-1-0-0-0                    AAACCTGAGCCACCTG-1-0-0-0
# AAACCTGAGCGCTCCA-1-0-0-0                    AAACCTGAGCGCTCCA-1-0-0-0
# AAACCTGAGCTCCCAG-1-0-0-0                    AAACCTGAGCTCCCAG-1-0-0-0
# AAACCTGAGCTGAAAT-1-0-0-0                    AAACCTGAGCTGAAAT-1-0-0-0
# ...                                                              ...
# TTTGTCAGTACAGTGG-HT-188-Adult-Duo  TTTGTCAGTACAGTGG-HT-188-Adult-Duo
# TTTGTCAGTATATGAG-HT-188-Adult-Duo  TTTGTCAGTATATGAG-HT-188-Adult-Duo
# TTTGTCAGTCCAGTAT-HT-188-Adult-Duo  TTTGTCAGTCCAGTAT-HT-188-Adult-Duo
# TTTGTCATCATTGCCC-HT-188-Adult-Duo  TTTGTCATCATTGCCC-HT-188-Adult-Duo
# TTTGTCATCTCGCATC-HT-188-Adult-Duo  TTTGTCATCTCGCATC-HT-188-Adult-Duo
#
# [1267745 rows x 90 columns]

# %%
group = 'sampled_site_condition'

file_path = f"/Users/kylekimler/Projects/GCA/June2024_meeting/plots/{group}_summary.png"

# Example usage
plot = create_faceted_bar_graph(meta, 
                                grouping_var=group, 
                                color_palette = ['#172984','#8AD6E8', '#CEF7A0'], 
                                # stacking_var='title', 
                                # stacking_values=['Krzak2023', 'Boland2020']
                               )

wid = 16
hi = 5
print(plot + theme(figure_size=(wid, hi)))
plot.save(filename=file_path, width=wid, height=hi, units='in', dpi=300)
# Out:
# /var/folders/zc/5fly3ly908xb0pd8zy6m6bj80000gn/T/ipykernel_51477/2626253658.py:15: FutureWarning: Using print(plot) to draw and show the plot figure is deprecated and will be removed in a future version. Use plot.show().
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/themes/themeable.py:2419: FutureWarning: You no longer need to use subplots_adjust to make space for the legend or text around the panels. This paramater will be removed in a future version. You can still use 'plot_margin' 'panel_spacing' for your other spacing needs.
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:606: PlotnineWarning: Saving 16 x 5 in image.
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:607: PlotnineWarning: Filename: /Users/kylekimler/Projects/GCA/June2024_meeting/plots/sampled_site_condition_summary.png
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/themes/themeable.py:2419: FutureWarning: You no longer need to use subplots_adjust to make space for the legend or text around the panels. This paramater will be removed in a future version. You can still use 'plot_margin' 'panel_spacing' for your other spacing needs.

# %%
group = 'disease_free_text'

file_path = f"/Users/kylekimler/Projects/GCA/June2024_meeting/plots/{group}_summary.png"

# Example usage
plot = create_faceted_bar_graph(meta, 
                                grouping_var=group, 
                                color_palette = ['#172984','#8AD6E8', '#CEF7A0'], 
                                # stacking_var='title', 
                                # stacking_values=['Krzak2023', 'Boland2020']
                               )

wid = 25
hi = 5
print(plot + theme(figure_size=(wid, hi)))
plot.save(filename=file_path, width=wid, height=hi, units='in', dpi=300)
# Out:
# /var/folders/zc/5fly3ly908xb0pd8zy6m6bj80000gn/T/ipykernel_51477/456614917.py:15: FutureWarning: Using print(plot) to draw and show the plot figure is deprecated and will be removed in a future version. Use plot.show().
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/themes/themeable.py:2419: FutureWarning: You no longer need to use subplots_adjust to make space for the legend or text around the panels. This paramater will be removed in a future version. You can still use 'plot_margin' 'panel_spacing' for your other spacing needs.
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:606: PlotnineWarning: Saving 25 x 5 in image.
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:607: PlotnineWarning: Filename: /Users/kylekimler/Projects/GCA/June2024_meeting/plots/disease_free_text_summary.png
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/themes/themeable.py:2419: FutureWarning: You no longer need to use subplots_adjust to make space for the legend or text around the panels. This paramater will be removed in a future version. You can still use 'plot_margin' 'panel_spacing' for your other spacing needs.

# %%
group = 'assay_ontology_term'

file_path = f"/Users/kylekimler/Projects/GCA/June2024_meeting/plots/{group}_summary.png"

# Example usage
plot = create_faceted_bar_graph(meta, 
                                grouping_var=group, 
                                color_palette = ['#172984','#8AD6E8', '#CEF7A0'], 
                                # stacking_var='title', 
                                # stacking_values=['Krzak2023', 'Boland2020']
                               )

wid = 16
hi = 5
print(plot + theme(figure_size=(wid, hi)))
plot.save(filename=file_path, width=wid, height=hi, units='in', dpi=300)
# Out:
# /var/folders/zc/5fly3ly908xb0pd8zy6m6bj80000gn/T/ipykernel_51477/518992076.py:15: FutureWarning: Using print(plot) to draw and show the plot figure is deprecated and will be removed in a future version. Use plot.show().
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/themes/themeable.py:2419: FutureWarning: You no longer need to use subplots_adjust to make space for the legend or text around the panels. This paramater will be removed in a future version. You can still use 'plot_margin' 'panel_spacing' for your other spacing needs.
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:606: PlotnineWarning: Saving 16 x 5 in image.
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:607: PlotnineWarning: Filename: /Users/kylekimler/Projects/GCA/June2024_meeting/plots/assay_ontology_term_summary.png
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/themes/themeable.py:2419: FutureWarning: You no longer need to use subplots_adjust to make space for the legend or text around the panels. This paramater will be removed in a future version. You can still use 'plot_margin' 'panel_spacing' for your other spacing needs.

# %%
group = 'sample_preservation_method'

file_path = f"/Users/kylekimler/Projects/GCA/June2024_meeting/plots/{group}_summary.png"

# Example usage
plot = create_faceted_bar_graph(meta, 
                                grouping_var=group, 
                                color_palette = ['#172984','#8AD6E8', '#CEF7A0'], 
                                # stacking_var='title', 
                                # stacking_values=['Krzak2023', 'Boland2020']
                               )

wid = 16
hi = 5
print(plot + theme(figure_size=(wid, hi)))
plot.save(filename=file_path, width=wid, height=hi, units='in', dpi=300)
# Out:
# /var/folders/zc/5fly3ly908xb0pd8zy6m6bj80000gn/T/ipykernel_51477/3684897541.py:15: FutureWarning: Using print(plot) to draw and show the plot figure is deprecated and will be removed in a future version. Use plot.show().
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/themes/themeable.py:2419: FutureWarning: You no longer need to use subplots_adjust to make space for the legend or text around the panels. This paramater will be removed in a future version. You can still use 'plot_margin' 'panel_spacing' for your other spacing needs.
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:606: PlotnineWarning: Saving 16 x 5 in image.
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/ggplot.py:607: PlotnineWarning: Filename: /Users/kylekimler/Projects/GCA/June2024_meeting/plots/sample_preservation_method_summary.png
# /Users/kylekimler/.pyenv/versions/3.11.8/lib/python3.11/site-packages/plotnine/themes/themeable.py:2419: FutureWarning: You no longer need to use subplots_adjust to make space for the legend or text around the panels. This paramater will be removed in a future version. You can still use 'plot_margin' 'panel_spacing' for your other spacing needs.

# %%
# Out:
# AnnData object with n_obs × n_vars = 1510893 × 59254
#     obs: 'title', 'donor_id_x', 'sample_id', 'publication_doi', 'institute', 'contact_email', 'reference_genome', 'gene_annotation_version', 'alignment_software', 'intron_inclusion', 'ambient_count_correction', 'doublet_detection', 'study_pi', 'batch_condition', 'default_embedding', 'comments', 'protocol_url', 'consortia', 'description', 'worksheet_x', 'organism_ontology_term_id', 'manner_of_death', 'sex_ontology_term_id', 'disease_free_text', 'disease_ontology_term_id', 'disease_ontology_term', 'self_reported_ethnicity_ontology_term_id', 'worksheet_y', 'organism', 'disease', 'self_reported_ethnicity_term_id', 'sample_collection_relative_time_point', 'sample_source', 'sample_collection_method', 'tissue_type', 'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_ontology_term', 'radial_tissue_term', 'sample_preservation_method', 'suspension_type', 'cell_enrichment', 'sample_collection_year', 'assay_ontology_term_id', 'sequenced_fragment', 'assay_ontology_term', 'development_stage_ontology_term_id', 'age_range', 'sample_collection_time_point', 'library_id', 'sample_uniqueness', 'n_cells', 'n_genes', 'total_n_reads', 'min_n_reads', 'median_n_reads', 'max_n_reads', 'min_fraction_MT_reads', 'median_fraction_MT_reads', 'max_fraction_MT_reads', 'tissue_free_text', 'worksheet', 'sample_collection_site', 'sequencing_platform', 'tissue', 'donor_id_y', 'library_id_repository', 'cell_viability_percentage', 'cell_number_loaded', 'library_preparation_batch', 'library_sequencing_run', 'donor_id', 'author_cell_type', 'cell_ontology_term_id', 'cell_id', 'cell_count_per_donor'
#     obsm: 'X_PCA', 'X_UMAP', 'X_mde', 'X_pca', 'X_pca_harmony', 'X_scANVI', 'X_tsne', 'X_umap', '_scvi_extra_continuous_covs'
#     layers: 'counts', 'ln_rpdm-normalized', 'log1p_cp10k', 'raw_rpdm-normalized'
